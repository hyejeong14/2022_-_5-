# %%
import numpy as np
import pandas as pd
import re
import networkx as nx
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import LancasterStemmer

from PIL import Image
from collections import Counter

# %%
df = pd.read_csv('all_review_.csv')
df
# Out:
#        Unnamed: 0  STAR                                            CONTENT
# 0               0     5  Seoul tower is very peacfull and one of clean ...
# 1               1     4   We have walked up and down It is a good walk ...
# 2               2     4   It was a bit late to open and it was raining ...
# 3               3     5   It was nice to be able to see the beautiful n...
# 4               4     5  Got there at dusk By the time we got into the ...
# ...           ...   ...                                                ...
# 15460       15466     5                Dream  of a very well planned place
# 15461       15467     5     Christmas organized the event very beautifully
# 15462       15468     4                                                Wow
# 15463       15469     5                              Excelente experiencia
# 15464       15470     3   Too many people but pretty A good place to ta...
#
# [15465 rows x 3 columns]

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# STAR          0
# CONTENT       0
# dtype: int64

# %%
#불용어 추가
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
#add_stop_words = ["'", ",", "'s", ":", ".", "?", "!","(",")","n't","korea","korean","good","like","awesome","perfect","nice","well","great","seoul","expensive","beautiful","wonderful","view","views","city","place","visit","tower","just","lotte","world","went","lotte","tower","street","lot","lots","ddp","insadong","places","bookstore","bookstores","books","kyobo","lotte","aquarium","feel","animals","park","animals","coex","mall","great","pretty","best"]
add_stop_words = ["'", ",", "'s", ":", ".", "?", "!","(",")","n't","korea","korean","go","went","just","seoul","visit","lot","lots","feel"]
for word in add_stop_words:
    stop_words.add(word)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiu14\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiu14\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiu14\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text = df[['CONTENT']]
text
# Out:
#                                                  CONTENT
# 0      Seoul tower is very peacfull and one of clean ...
# 1       We have walked up and down It is a good walk ...
# 2       It was a bit late to open and it was raining ...
# 3       It was nice to be able to see the beautiful n...
# 4      Got there at dusk By the time we got into the ...
# ...                                                  ...
# 15460                Dream  of a very well planned place
# 15461     Christmas organized the event very beautifully
# 15462                                                Wow
# 15463                              Excelente experiencia
# 15464   Too many people but pretty A good place to ta...
#
# [15465 rows x 1 columns]

# %%
from nltk.stem import WordNetLemmatizer
text = df[['CONTENT']]

text_arr=[[]for i in range(len(df['CONTENT']))]
#토큰화
text['CONTENT'] = text.apply(lambda row: nltk.word_tokenize(row['CONTENT']), axis=1)

#불용어 처리
text['CONTENT'] = text['CONTENT'].apply(lambda x: [word.lower() for word in x])
text['CONTENT'] = text['CONTENT'].apply(lambda x: [word for word in x if word not in (stop_words)])

#표제어 추출
text['CONTENT'] = text['CONTENT'].apply(lambda x : [WordNetLemmatizer().lemmatize(word, pos='v') for word in x])
    
#길이가 3이하인 단어에 대해서 제거하는 작업을 수행
tokenized_doc = text['CONTENT'].apply(lambda x : [word for word in x if len(word) > 3])
    
#tf-idf 행렬을 만들기 위해 역토큰화
detokenized_doc = []
for i in range(len(text)):
    t = ' '.join(tokenized_doc[i])
    detokenized_doc.append(t)
text['CONTENT'] = detokenized_doc
    
text_arr=[]

for i in text['CONTENT']:
    i=i.split()
    text_arr.append(i)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_14276\550990889.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text['CONTENT'] = text.apply(lambda row: nltk.word_tokenize(row['CONTENT']), axis=1)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_14276\550990889.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text['CONTENT'] = text['CONTENT'].apply(lambda x: [word.lower() for word in x])
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_14276\550990889.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text['CONTENT'] = text['CONTENT'].apply(lambda x: [word for word in x if word not in (stop_words)])
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_14276\550990889.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text['CONTENT'] = text['CONTENT'].apply(lambda x : [WordNetLemmatizer().lemmatize(word, pos='v') for word in x])
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_14276\550990889.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text['CONTENT'] = detokenized_doc

# %%
text_arr
# Out:
# [['tower',
#   'peacfull',
#   'clean',
#   'place',
#   'life',
#   'beautiful',
#   'city',
#   'view',
#   'fantastic',
#   'garden',
#   'tree',
#   'highly',
#   'suggest',
#   'must',
#   'book',
#   'list',
#   'come',
#   'place',
#   'love',
#   'spend',
#   'time'],
#  ['walk',
#   'good',
#   'walk',
#   'side',
#   'stairs',
#   'path',
#   'forest',
#   'visibility',
#   'bite',
#   'poor',
#   'expect',
#   'cloudy',
#   'weather'],
#  ['bite', 'late', 'open', 'rain', 'hard', 'wait', 'outside', 'still', 'good'],
#  ['nice', 'able', 'beautiful', 'night', 'view'],
#  ['dusk',
#   'time',
#   'tower',
#   'dark',
#   'would',
#   'better',
#   'earlier',
#   'foothills',
#   'time',
#   'wouldnt',
#   'allow',
#   'stun',
#   'view',
#   'city'],
#  ['long',
#   'time',
#   'since',
#   'visit',
#   'mother',
#   'children',
#   'night',
#   'view',
#   'even',
#   'weekend',
#   'many',
#   'visitors',
#   'kosiguk'],
#  ['years',
#   'didnt',
#   'like',
#   'much',
#   'joke',
#   'expensive',
#   'offer',
#   'seem',
#   'attractions',
#   'south',
#   'kpop',
#   'kdramas',
#   'palaces',
#   'anything'],
#  ['overlook'],
#  ['cool',
#   'weather',
#   'many',
#   'tree',
#   'convenient',
#   'walk',
#   'morning',
#   'exercise',
#   'cafe',
#   'tower',
#   'spacious',
#   'outdoor',
#   'space'],
#  ['worth', 'beautiful', 'landmarks'],
#  ['cable', 'pork', 'cutlet', 'good', 'date'],
#  ['point', 'worth', 'visit'],
#  ['namsan',
#   'tower',
#   'build',
#   '1969',
#   'koreas',
#   'first',
#   'integrate',
#   'transmission',
#   'tower',
#   'beam',
#   'television',
#   'radio',
#   'broadcast',
#   'across',
#   'capital',
#   'since',
#   'open',
#   'public',
#   '1980',
#   'become',
#   'muchloved',
#   'landmark',
#   'tower',
#   'main'],
#  ['like',
#   'doubledecker',
#   'tower',
#   'feel',
#   'different',
#   'nice',
#   'arrive',
#   'tower',
#   'look',
#   'around'],
#  ['buran', 'place'],
#  ['nice', 'ride', 'nice', 'view', 'city'],
#  [],
#  ['tower',
#   'quite',
#   'time',
#   'mostly',
#   'walk',
#   'easy',
#   'walk',
#   'swear',
#   'cable',
#   'option',
#   'prefer',
#   'less',
#   'active',
#   'plenty',
#   'grab',
#   'something'],
#  ['arrive',
#   'namsan',
#   'library',
#   'around',
#   'morning',
#   'park',
#   'take',
#   'minutes',
#   'walk',
#   'namsan',
#   'tower'],
#  ['nice',
#   'small',
#   'hike',
#   'tower',
#   'plenty',
#   'restoraunts',
#   'well',
#   'choose',
#   'scenic',
#   'view',
#   'overall',
#   'great',
#   'experinece',
#   'right',
#   'city'],
#  ['dont',
#   'take',
#   'namsan',
#   'tower',
#   'cable',
#   '20minute',
#   'walk',
#   'park',
#   'park',
#   'little',
#   'hard',
#   'stairs'],
#  ['okay', 'think', 'would', 'nice', 'little', 'dynamic'],
#  ['favorite', 'place'],
#  ['cool', 'location', 'extremly', 'nice', '360degview', 'town'],
#  ['great',
#   'view',
#   'city',
#   'nice',
#   'place',
#   'relax',
#   'chill',
#   'summer',
#   'take',
#   'cable',
#   'myeongdong'],
#  ['great', 'place', 'view', 'skyline'],
#  ['turn',
#   'climb',
#   'tower',
#   'wait',
#   'night',
#   'view',
#   'around',
#   'tower',
#   'beautiful',
#   'enough',
#   'course',
#   'night',
#   'view',
#   'tower',
#   'best'],
#  ['picture',
#   'bongsudae',
#   'next',
#   'metropolitan',
#   'city',
#   'cultural',
#   'heritage',
#   'excavation',
#   'exhibition',
#   'hall',
#   'namsan',
#   'tower'],
#  ['night',
#   'view',
#   'indeed',
#   'first',
#   'recommendation',
#   'unfortunately',
#   'hurry',
#   'passerby',
#   'stay',
#   'night',
#   'didnt',
#   'ticket',
#   'tower',
#   'take',
#   'next',
#   'step'],
#  ['visit',
#   'place',
#   'summer',
#   'huge',
#   'mistake',
#   'line',
#   'unbelievably',
#   'long',
#   'slow',
#   'never',
#   'long',
#   'line',
#   'force',
#   'stand',
#   'dont',
#   'want',
#   'walk',
#   'stairs',
#   'summer',
#   'round',
#   'ticket'],
#  ['always',
#   'want',
#   'namsan',
#   'tower',
#   'beautiful',
#   'view',
#   'highly',
#   'recommend'],
#  ['nice', 'able', 'downtown', 'glance', 'weekdays', 'half', 'foreigners'],
#  ['cloudy',
#   'ticket',
#   'observatory',
#   'stamp',
#   'free',
#   'come',
#   'back',
#   'within',
#   'months',
#   'system',
#   'fine'],
#  ['great'],
#  ['tower', 'worth', 'traditional', 'martial', 'arts', 'performances', 'tower'],
#  ['good'],
#  ['entry',
#   'ticket',
#   'little',
#   'pricey',
#   'especially',
#   'also',
#   'cable',
#   'ticket',
#   'base',
#   'dont',
#   'want',
#   'hike',
#   'think',
#   'quite',
#   'worth',
#   'view',
#   'great',
#   'also',
#   'shop',
#   'drink'],
#  ['worth', 'restaurants', 'cafes'],
#  ['fulfil',
#   'bucket',
#   'list',
#   'sons',
#   'live',
#   'farther',
#   'place',
#   'play',
#   'embarrass',
#   'never',
#   'nearby',
#   'namsan',
#   'mountain'],
#  ['good', 'scenery', 'superb'],
#  ['really',
#   'mandatory',
#   'enter',
#   'bucketlist',
#   'namsan',
#   'tower',
#   'icon',
#   'road',
#   'bite',
#   'uphill',
#   'bite',
#   'messy',
#   'really',
#   'worth'],
#  ['love', 'place'],
#  ['amaze', 'view'],
#  ['favorite', 'place', 'modest', 'often', 'easily', 'whole', 'view'],
#  ['good', 'place', 'entirety', 'also', 'good', 'place', 'coffee', 'date'],
#  ['nice', 'take', 'cable', 'tower'],
#  ['couldnt',
#   'well',
#   'weather',
#   'revisit',
#   'within',
#   'months',
#   'stamp',
#   'free'],
#  ['long', 'time', 'quite', 'people', 'even', 'rainy', 'weather', 'foreigners'],
#  ['escalator',
#   'cable',
#   'myeongdong',
#   'charge',
#   'place',
#   'play',
#   'variously',
#   'restaurants',
#   'cafes',
#   'whole'],
#  ['tollerest', 'tower'],
#  ['almost', 'city', 'foggy'],
#  ['namsan',
#   'tower',
#   'know',
#   'tower',
#   'high',
#   'tower',
#   'center',
#   'tower',
#   'high',
#   'meter',
#   'become',
#   'higher',
#   'tower',
#   'south',
#   'tower',
#   'build',
#   'december',
#   '1969',
#   'need',
#   'years'],
#  ['great',
#   'place',
#   'good',
#   'view',
#   'also',
#   'great',
#   'place',
#   'hang',
#   'exercise',
#   'plenty',
#   'food',
#   'shop',
#   'toilets',
#   'dont',
#   'want',
#   'walk'],
#  ['wind',
#   'cool',
#   'nice',
#   'walk',
#   'pork',
#   'cutlet',
#   'tower',
#   'plaza',
#   'delicious'],
#  ['especially',
#   'night',
#   'view',
#   'breathtaking',
#   'tower',
#   'illuminate',
#   'different',
#   'color'],
#  ['beautiful'],
#  ['amaze', 'tower', 'dissepoinding'],
#  ['view', 'city', 'great', 'easily', 'hike', 'take'],
#  ['amaze', 'place'],
#  ['superb',
#   'experience',
#   'whole',
#   'absolutely',
#   'must',
#   'thing',
#   'visit',
#   'first',
#   'time'],
#  ['cable', '50000', 'family', 'four', '50000', 'tower', 'observatory'],
#  ['walk',
#   'hotel',
#   'myeongdong',
#   'price',
#   'pretty',
#   'normal',
#   'enjoy',
#   'sight',
#   'walk',
#   'path',
#   'tower',
#   'take',
#   'gondola',
#   'small',
#   'tower'],
#  ['love', 'egypt', 'hope'],
#  ['whole', 'city', 'glance', 'luckily', 'rainbow'],
#  ['visit', 'hongdae', 'street', 'long', 'time', 'change'],
#  ['feijing',
#   'beautiful',
#   'watch',
#   'sunset',
#   'even',
#   'night',
#   'view',
#   'night',
#   'glance',
#   'highly',
#   'recommend',
#   'come'],
#  ['place', 'wont', 'unless', 'make', 'mind'],
#  ['many',
#   'people',
#   'cost',
#   '14000',
#   'condition',
#   'cable',
#   'unavailable',
#   'vacation',
#   'heat',
#   'people'],
#  ['namsan',
#   'cable',
#   '7000',
#   'minutes',
#   'expensive',
#   'people',
#   'round',
#   'trip',
#   '42000',
#   'think',
#   '4000',
#   'appropriate'],
#  ['convenient', 'place', 'around', 'stroller', 'staff', 'friendly'],
#  ['bite', 'pricey', 'ride', 'funicular', 'nice', 'view'],
#  ['hallmarks',
#   'beautiful',
#   'tower',
#   'part',
#   'experience',
#   'either',
#   'take',
#   'cable',
#   'path',
#   'tower',
#   'amaze',
#   'admire',
#   'great',
#   'view',
#   'city',
#   'even',
#   'reach',
#   'tower'],
#  ['love', 'seuol', 'pepole'],
#  ['namsan',
#   'already',
#   'hanyang',
#   'good',
#   'place',
#   'walk',
#   'cable',
#   'ride',
#   'although',
#   'gilnyangies',
#   'place',
#   'phytoncides'],
#  ['weather',
#   'good',
#   'whole',
#   'view',
#   'glance',
#   'place',
#   'open',
#   'heart',
#   'take',
#   'walk',
#   'free',
#   'time',
#   'transportation',
#   'still',
#   'inconvenient'],
#  ['beautiful', 'expect', 'cable', 'pack', 'haha'],
#  ['cold', 'foggy', 'time'],
#  ['stun',
#   'tower',
#   'overlook',
#   'inside',
#   'tower',
#   'projection',
#   'exhibition',
#   'room',
#   'reach',
#   'elevator',
#   'take',
#   'view',
#   'deck',
#   'near',
#   'around',
#   'tower',
#   'nature',
#   'reserve',
#   'serve',
#   'amaze',
#   'green',
#   'space',
#   'middle'],
#  ['place', 'scenery', 'glance'],
#  ['view',
#   'spectacular',
#   'worth',
#   'climb',
#   'train',
#   'station',
#   'hella',
#   'steep',
#   'humidity',
#   'lower',
#   'didnt',
#   'sweat',
#   'much'],
#  ['wonderful'],
#  ['view',
#   'good',
#   'route',
#   'inconvenient',
#   'take',
#   'different',
#   'route',
#   'couldnt',
#   'park',
#   'think',
#   'would',
#   'convenient',
#   'take',
#   'cable'],
#  ['view',
#   'mediocre',
#   'symbolic',
#   'mean',
#   'visit',
#   'mountain',
#   'behind',
#   'neighborhood',
#   'namsan',
#   'tower',
#   'locate',
#   'trip'],
#  ['honestly',
#   'expect',
#   'much',
#   'view',
#   'nothing',
#   'write',
#   'home',
#   'night',
#   'climb',
#   'quite',
#   'shabby',
#   'elevator',
#   'expensive',
#   'wait',
#   'nothing',
#   'else'],
#  ['beautiful', 'place', 'friends', 'couple'],
#  ['well',
#   'think',
#   'great',
#   'hope',
#   'dont',
#   'neglect',
#   'management',
#   'surround',
#   'facilities',
#   'foreigners',
#   'come',
#   'would',
#   'nice',
#   'variety',
#   'events',
#   'events'],
#  ['first', 'namsan', 'tower', 'watch', 'tonkatsu', 'really', 'cable'],
#  ['hike',
#   'tower',
#   'miles',
#   'away',
#   'backpack',
#   'onthe',
#   'hike',
#   'pave',
#   'step',
#   'step',
#   'pretty',
#   'sweaty',
#   'wind',
#   'time',
#   'make',
#   'tower'],
#  ['amaze',
#   'place',
#   'night',
#   'view',
#   'city',
#   'amaze',
#   'better',
#   'even',
#   'time',
#   'view',
#   'night',
#   'together',
#   'little',
#   'crowd',
#   'night',
#   'seat',
#   'arrangements',
#   'good',
#   'dont',
#   'ticket',
#   'advance'],
#  ['entrance',
#   'expensive',
#   'facilities',
#   'good',
#   'felt',
#   'dirty',
#   'strange',
#   'smell',
#   'like',
#   'toilet',
#   'smell',
#   'souvenirs',
#   'also'],
#  ['love',
#   'view',
#   'even',
#   'though',
#   'rain',
#   'definitely',
#   'back',
#   'experience',
#   'attractions'],
#  ['breath', 'take'],
#  ['lovely', 'view', 'great', 'shop'],
#  ['excellent', 'view', 'food'],
#  ['sometimes', 'good', 'convenient', 'take', 'direct'],
#  ['nice',
#   'able',
#   'night',
#   'view',
#   'glance',
#   'enjoy',
#   'walk',
#   'cable',
#   'highly',
#   'recommend',
#   'seek',
#   'comfort'],
#  ['beautiful'],
#  ['visit',
#   'namsan',
#   'tower',
#   'first',
#   'time',
#   'decades',
#   'youve',
#   'transform',
#   'really',
#   'nicely',
#   'closer',
#   'live',
#   'less',
#   'likely',
#   'sure',
#   'back'],
#  ['view'],
#  ['nice', 'view'],
#  ['nice', 'place', 'city'],
#  ['nice',
#   'place',
#   'improve',
#   'spacious',
#   'area',
#   'easy',
#   'walk',
#   'beautiful',
#   'photography',
#   'good',
#   'nature'],
#  ['nice', 'view', 'cafes', 'still', 'close', 'pandemic'],
#  ['cool', 'view', 'small', 'congestion', 'tower'],
#  ['bless', 'heaven', 'namsan', 'middle', 'downtown'],
#  ['place', 'enjoy', 'beautiful', 'night'],
#  ['tower',
#   'remarkable',
#   'landmark',
#   'people',
#   'overlook',
#   'city',
#   'visitors',
#   'tram',
#   'walk',
#   'take',
#   'tram',
#   'need',
#   'ticket',
#   'also',
#   'save',
#   'time',
#   'physical'],
#  ['truly',
#   'heart',
#   'make',
#   'pilgrimage',
#   'today',
#   'walk',
#   'meditate',
#   'beauty'],
#  ['interest'],
#  ['believe', 'dream', 'come', 'true', 'hope', 'begin', 'everything'],
#  ['good'],
#  ['nice', 'worth'],
#  ['like', 'many', 'lovers', 'many', 'families'],
#  ['view', 'nice', 'ticket'],
#  ['several', 'time', 'visit', 'first', 'time'],
#  ['bite',
#   'disappoint',
#   'come',
#   'money',
#   'nice',
#   'view',
#   'cant',
#   'anywhere',
#   'else',
#   'find',
#   'build',
#   'neighborhood',
#   'know'],
#  ['dont',
#   'need',
#   'tower',
#   'beautiful',
#   'view',
#   'observation',
#   'podiums',
#   'hill',
#   'lock',
#   'love',
#   'thousands',
#   'thousands'],
#  ['must', 'enjoy', 'view'],
#  ['great',
#   'view',
#   'city',
#   'take',
#   'elevator',
#   'cable',
#   'stairs',
#   'lift',
#   'plan',
#   'time',
#   'sunset'],
#  ['night',
#   'view',
#   'good',
#   'cable',
#   'soso',
#   'park',
#   'public',
#   'park',
#   'confirmation',
#   'must',
#   'park'],
#  ['night',
#   'view',
#   'namsan',
#   'wonderful',
#   'view',
#   'daytime',
#   'also',
#   'wonderful',
#   'also',
#   'great',
#   'place',
#   'watch',
#   'sunset',
#   'outdoor',
#   'observatory',
#   'front',
#   'namsan',
#   'well',
#   'maintain',
#   'many',
#   'people'],
#  ['must', 'come', 'couple'],
#  ['take',
#   'cablecar',
#   'tower',
#   'little',
#   'wait',
#   'travel',
#   'view',
#   'area',
#   'amaze',
#   'view',
#   'second',
#   'namhansansong',
#   'night'],
#  ['cool',
#   'sight',
#   'take',
#   'cable',
#   'great',
#   'experience',
#   'nice',
#   'gift',
#   'shop'],
#  ['cool', 'place'],
#  ['amaze',
#   'view',
#   'need',
#   'past',
#   'observation',
#   'deck',
#   'lock',
#   'share',
#   'love',
#   'kitschy'],
#  [],
#  ['family',
#   'tour',
#   'good',
#   'part',
#   'free',
#   'museum',
#   'traditional',
#   'martial',
#   'arts',
#   'demonstration'],
#  ['take',
#   'night',
#   'time',
#   'hike',
#   'tower',
#   'beautiful',
#   'city',
#   'view',
#   'also',
#   'take'],
#  ['find', 'shuttle', 'tower', 'chungmuro', 'metro', 'station', 'exit'],
#  ['tower',
#   'many',
#   'attractions',
#   'something',
#   'consider',
#   'must',
#   'tourists',
#   'tower',
#   'locate',
#   'small',
#   'mountain',
#   'reach',
#   'cable',
#   'cars',
#   'even',
#   'hike'],
#  ['must', 'attractions'],
#  ['night',
#   'view',
#   'especially',
#   'beautiful',
#   'honestly',
#   'better',
#   'hong',
#   'kong',
#   'road',
#   'wide'],
#  ['bite', 'cloudy', 'nice', 'able', 'look', 'around', 'city'],
#  ['good', 'night', 'close', '10pm'],
#  ['nice',
#   'attraction',
#   'price',
#   'well',
#   'take',
#   'cable',
#   'walk',
#   'would',
#   'suggest',
#   'walk',
#   'stairs',
#   'around',
#   '1830',
#   'could',
#   'night',
#   'really',
#   'cloudy',
#   'today',
#   'range',
#   'limit',
#   'busy'],
#  ['glance',
#   'need',
#   'observatory',
#   'easy',
#   'food',
#   'taste',
#   'good',
#   'scenery',
#   'good',
#   'worth'],
#  ['really',
#   'nice',
#   'place',
#   'cable',
#   'relax',
#   'manner',
#   'await',
#   'many',
#   'possibilities',
#   'attach',
#   'memories',
#   'form',
#   'time',
#   'capsule',
#   'lock',
#   'special',
#   'devices',
#   'many'],
#  ['night', 'view', 'nice', 'crowd', 'many', 'people'],
#  ['best',
#   'place',
#   'command',
#   'good',
#   'view',
#   'also',
#   'good',
#   'walk',
#   'mild',
#   'intensity',
#   'take',
#   'cable',
#   'significantly',
#   'discount',
#   'purchase',
#   'round',
#   'trip',
#   'ticket',
#   'compare',
#   'oneway',
#   'ticket'],
#  ['night', 'view', 'family', 'weekend', 'wonderful'],
#  ['worth'],
#  ['clear', 'view', 'colorful', 'scenery'],
#  ['namsan',
#   'bongsu',
#   'martial',
#   'arts',
#   'team',
#   'perform',
#   'minutes',
#   'cool',
#   'bamboo',
#   'real',
#   'swords',
#   'different',
#   'size'],
#  ['good', 'time', 'family', 'mandatory', 'place'],
#  ['amaze', 'view'],
#  ['whole',
#   'city',
#   'visible',
#   'height',
#   'awesome',
#   'experience',
#   'floor',
#   'magic',
#   'music',
#   'video'],
#  ['night', 'view', 'fantastic'],
#  ['enjoy', 'night', 'view', 'follow', 'tiktok', 'ezatravel94'],
#  ['suggest',
#   'restaurants',
#   'stay',
#   'open',
#   'later',
#   '830pm',
#   'tourist',
#   'destination',
#   'would',
#   'like',
#   'halaal',
#   'restaurants'],
#  ['cable',
#   'expensive',
#   'easy',
#   'strollers',
#   'helpful',
#   'place',
#   'stairs',
#   'save',
#   'energy'],
#  ['night', 'view', 'wonderful', 'wish', 'table', 'chair', 'twosome', 'place'],
#  ['well', 'could', 'call', 'observation', 'hill'],
#  ['tower',
#   'namsan',
#   'tower',
#   'establish',
#   'landmark',
#   'tourist',
#   'attraction',
#   'long',
#   'time'],
#  ['great', 'view', 'must', 'tourists'],
#  ['didnt',
#   'reach',
#   'open',
#   'hours',
#   'tower',
#   'cable',
#   'view',
#   'pretty',
#   'amaze',
#   'worth',
#   'reach',
#   'even',
#   'dont',
#   'tower'],
#  ['pretty',
#   'night',
#   'stumble',
#   'upon',
#   'concert',
#   'orchestra',
#   'really',
#   'great'],
#  ['must', 'place', 'visit', 'whole', 'view', 'night', 'view', 'best', 'place'],
#  ['weekend',
#   'wait',
#   'hour',
#   'night',
#   'view',
#   'night',
#   'wonderful',
#   'much',
#   'observatory',
#   'open',
#   'would',
#   'nice',
#   'souvenir',
#   'shop',
#   'first',
#   'floor',
#   'open',
#   'late'],
#  ['namsan', 'always', 'good', 'climb'],
#  ['minutes',
#   'baekbeom',
#   'square',
#   'arrive',
#   'tower',
#   'mountains',
#   'best',
#   'time',
#   'look',
#   'enjoy',
#   'scenery'],
#  ['great', 'view', 'city', 'worth', 'visit'],
#  ['atmosphere', 'song', 'seem', 'everywhere', 'well'],
#  ['time',
#   'place',
#   'sunday',
#   'situate',
#   'mountain',
#   'ways',
#   'reach',
#   'either',
#   'take',
#   'cable',
#   'hike',
#   'choose',
#   'second',
#   'option',
#   'steep',
#   'hike'],
#  ['people',
#   'weekend',
#   'bite',
#   'difficult',
#   'wait',
#   'line',
#   'cable',
#   'observatory',
#   'stop',
#   'surround',
#   'area',
#   'ceremony'],
#  ['nice',
#   'place',
#   'clean',
#   'icon',
#   'city',
#   'also',
#   'padlock',
#   'whose',
#   'myth',
#   'lock',
#   'love',
#   'last',
#   'forever',
#   'iconic',
#   'transportation',
#   'also',
#   'easy'],
#  ['best',
#   'tourist',
#   'spot',
#   'cant',
#   'park',
#   'nearby',
#   'take',
#   'yellow',
#   'hill'],
#  ['calm', 'place', 'favorite', 'rest', 'course', 'rest', 'little', 'hike'],
#  ['adventure', 'visit', '2022', 'pakistan'],
#  ['great',
#   'spot',
#   'look',
#   'visit',
#   'even',
#   'good',
#   'choice',
#   'enjoy',
#   'daytime',
#   'view',
#   'night',
#   'view',
#   'take',
#   'cable',
#   'peak',
#   'coffee',
#   'wait',
#   'sunset',
#   'enjoy',
#   'breathtaking',
#   'view'],
#  ['speak', 'south', 'nostalgic', 'good', 'many', 'couple'],
#  ['beautiful', 'view', 'worth', 'climb'],
#  ['foreigner', 'visit', 'purchase', 'discount', 'ticket', 'online', 'advance'],
#  ['solid',
#   'hike',
#   'didnt',
#   'tower',
#   'cable',
#   'bite',
#   'exercise',
#   'close',
#   'myeongdong',
#   'area',
#   'worth',
#   'look',
#   'clear',
#   'beautiful'],
#  ['tower', 'close', 'ride', 'cable', 'good'],
#  ['awesome',
#   'tower',
#   'didnt',
#   'still',
#   'quite',
#   'view',
#   'free',
#   'areas',
#   'really',
#   'accessible',
#   'shuttle',
#   'sure',
#   'catch',
#   'cultural',
#   'performance',
#   'afternooncool',
#   'stuff',
#   'swords'],
#  ['recommend', 'dark', 'beautiful'],
#  ['good', 'view'],
#  ['take', 'circular', 'closer', 'convenient', 'cable', 'tooth'],
#  ['incredible', 'place', 'make', 'precious'],
#  ['ihan',
#   'kiva',
#   'torni',
#   'hyvt',
#   'nkalat',
#   'sumuisellakin',
#   'melko',
#   'kauas',
#   'tosin',
#   'kaupat',
#   'ravintolat',
#   'olivat',
#   'turhan',
#   'hintavia',
#   'lauantaina',
#   'paljon',
#   'plussaa',
#   'tiedosta',
#   'etisyydest',
#   'helsinkiin',
#   '11973'],
#  ['also',
#   'work',
#   'never',
#   'namsan',
#   'tower',
#   'time',
#   'wife',
#   'climb',
#   'namsan',
#   'tower',
#   'cable',
#   'first',
#   'time',
#   'facilities',
#   'good',
#   'view',
#   'good'],
#  ['first',
#   'time',
#   'visit',
#   'namsan',
#   'tower',
#   'nice',
#   'place',
#   'spend',
#   'weekend'],
#  ['didnt',
#   'tower',
#   'base',
#   'view',
#   'priceless',
#   'lotte',
#   'bridge',
#   'icon',
#   'city',
#   'must'],
#  ['good', 'view'],
#  ['great'],
#  ['crazy',
#   'experience',
#   'love',
#   'right',
#   'place',
#   'nature',
#   'modernity',
#   'embrace'],
#  ['highspeed',
#   'drive',
#   'second',
#   'good',
#   'climb',
#   'pity',
#   '18000',
#   'bite',
#   'expensive'],
#  [],
#  ['must', 'youre', 'sunny', 'also', 'recommend', 'sunset'],
#  ['observatory', 'experience', 'wonderful', 'night', 'view'],
#  ['sundays',
#   'folks',
#   'life',
#   'include',
#   'grandma',
#   'stick',
#   'journey',
#   'train',
#   'walk',
#   '15min',
#   'hill',
#   'ride',
#   'cable',
#   'back',
#   'walk',
#   'hill'],
#  ['best', 'view', 'free', 'want', 'better', 'view', 'tower'],
#  ['lock', 'dont', 'forget', 'hang', 'fence'],
#  ['perfect',
#   'place',
#   'complete',
#   'city',
#   'view',
#   'view',
#   'observatory',
#   'deck',
#   'truly',
#   'amaze',
#   'interest',
#   'part',
#   'come',
#   'dont',
#   'miss',
#   'place'],
#  ['wonderful'],
#  ['good',
#   'experience',
#   'need',
#   'spend',
#   'much',
#   'money',
#   'cheapest',
#   'place',
#   'travel'],
#  ['short',
#   'hike',
#   'beautiful',
#   'require',
#   'instead',
#   'entries',
#   'different',
#   'visitors',
#   'glad',
#   'local',
#   'know',
#   'love',
#   'lock',
#   'cool',
#   'music',
#   'dancers'],
#  ['love', 'recommend', 'everyone'],
#  ['crowd', 'people', 'come', 'play', 'family', 'foreigners'],
#  [],
#  ['come', 'even', 'catch', 'clear', 'view', 'city', 'sunset'],
#  ['excellent', 'view', 'city'],
#  ['lovely', 'night', 'full', 'memories'],
#  ['beautiful',
#   'track',
#   'namsan',
#   'tower',
#   'come',
#   'back',
#   'walk',
#   'recommend'],
#  ['nice', 'view'],
#  ['come',
#   'young',
#   'think',
#   'first',
#   'time',
#   'grow',
#   'first',
#   'time',
#   'decades',
#   'cloudy',
#   'occasional',
#   'rain',
#   'windy'],
#  ['good', 'place', 'sunset', 'recommend'],
#  ['super', 'view', 'worth', 'trip'],
#  ['many',
#   'cities',
#   'worldwide',
#   'fair',
#   'share',
#   'observation',
#   'tower',
#   'sadly',
#   'worst',
#   'whoever',
#   'design',
#   'observation',
#   'deck',
#   'research',
#   'make',
#   'good'],
#  ['night',
#   'view',
#   'beautiful',
#   'hwahwa',
#   'station',
#   'although',
#   'many',
#   'stairs',
#   'worth',
#   'namsan',
#   'tower',
#   'shop',
#   'mall',
#   'open',
#   '1000'],
#  ['nice', 'view'],
#  [],
#  ['observation', 'deck', 'city', 'view'],
#  ['bongsudae',
#   'good',
#   'samulnori',
#   'martial',
#   'arts',
#   'class',
#   'demonstrations',
#   'hold',
#   'oclock',
#   'wonderful',
#   'sure',
#   'check'],
#  ['walk', 'town', 'step', 'worth', 'even', 'admire', 'city', 'superb'],
#  ['stun', 'view', 'city'],
#  ['beautiful', 'view', 'live', 'entertainment'],
#  ['heongdae', 'gangnam', 'huke', 'take', 'wonderful'],
#  ['honor', 'high', 'tower'],
#  ['view', 'good', 'unlike', 'lotte', 'world', 'tower', 'every', 'corner'],
#  ['view', 'amaze', 'time', 'special', 'place', 'sure'],
#  ['namsan',
#   'tower',
#   'downtown',
#   'walk',
#   'like',
#   'climb',
#   'story',
#   'build',
#   'recommend',
#   'children',
#   'elderly'],
#  [],
#  ['come', 'must', 'least', 'like', 'sunset', 'night', 'view'],
#  [],
#  ['view',
#   'beautiful',
#   'even',
#   'climb',
#   'tower',
#   'view',
#   'beautiful',
#   'worth',
#   'least'],
#  ['weather', 'nice', 'surround', 'scenery', 'beautiful'],
#  ['great', 'view', 'city'],
#  ['thats', 'beautiful', 'place'],
#  ['cable', 'long', 'keep', 'move'],
#  ['good',
#   'except',
#   'huge',
#   'line',
#   'ride',
#   'cable',
#   'maybe',
#   'late',
#   'also',
#   'garbage',
#   'people'],
#  ['convenience',
#   'facilities',
#   'food',
#   'entertainment',
#   'common',
#   'scenery',
#   'good',
#   'overlook',
#   'glance'],
#  ['nice'],
#  ['attractions', 'good', 'walk'],
#  ['nice',
#   'place',
#   'almost',
#   'impossible',
#   'untill',
#   'certain',
#   'spot',
#   'hike',
#   '3040',
#   'minutes'],
#  ['excellent',
#   'tower',
#   'decent',
#   'experience',
#   'nice',
#   'view',
#   'enjoy',
#   'problem',
#   'really',
#   'crowd',
#   'hundreds',
#   'students',
#   'shout',
#   'perhaps',
#   'number',
#   'people',
#   'enter',
#   'restrict'],
#  ['good',
#   'place',
#   'look',
#   'seouls',
#   'skyline',
#   'entry',
#   'ticket',
#   'reasonably',
#   'cheap',
#   'isnt',
#   'much',
#   'observation',
#   'deck',
#   'unfortunately',
#   'windows',
#   'quite',
#   'dirty',
#   'viewsphotos',
#   'werent',
#   'good'],
#  ['best', 'spot', 'view', 'city'],
#  ['place', 'dream', 'want', 'know', 'explore', 'find'],
#  ['love', 'south'],
#  ['great',
#   'view',
#   'city',
#   'fair',
#   'price',
#   'book',
#   'klook',
#   'nearly',
#   'half',
#   'price',
#   'make',
#   'sure',
#   'restroom',
#   'insane',
#   'view',
#   'bathroom'],
#  ['namsan', 'uejeoppine', 'cable', 'wait', 'hour'],
#  ['another', 'iconic', 'tourist', 'attractions'],
#  ['worth'],
#  ['great', 'place', 'sport', 'relax', 'look', 'city', 'heightwaow'],
#  ['seem', 'play'],
#  ['seouls',
#   'famous',
#   'namsan',
#   'tower',
#   'stairs',
#   'first',
#   'time',
#   'weekday',
#   'stairs',
#   'revisions'],
#  ['cool',
#   'place',
#   'highest',
#   'city',
#   '12000',
#   'ticket',
#   'spend',
#   'time',
#   'light',
#   'show',
#   'downstairs',
#   'come'],
#  ['foggy',
#   'night',
#   'view',
#   'bite',
#   'disappoint',
#   'view',
#   'elevator',
#   'operate',
#   'many',
#   'people',
#   'inconvenient'],
#  ['everyone', 'admit', 'need'],
#  ['time',
#   'span',
#   'five',
#   'years',
#   'time',
#   'lock',
#   'outside',
#   'disgust',
#   'cant',
#   'remember',
#   'light',
#   'room',
#   'always',
#   'nice',
#   'addition',
#   'either',
#   'periscopes',
#   'amaze',
#   'coin',
#   'machine',
#   'seem',
#   'always',
#   'empty',
#   'service'],
#  ['must'],
#  ['enter', 'even', 'today', 'observation', 'tower', 'pasu'],
#  ['night',
#   'view',
#   'okay',
#   'corona',
#   'people',
#   'flock',
#   'ride',
#   'cable',
#   'hard'],
#  ['many',
#   'people',
#   'difficult',
#   'night',
#   'view',
#   'wait',
#   'time',
#   'long',
#   'inside',
#   'tower',
#   'cramp',
#   'recommend',
#   'octagonal',
#   'pavilion'],
#  ['even',
#   'number',
#   'ticket',
#   'booths',
#   'reduce',
#   'person',
#   'sales',
#   'counter',
#   'awaken'],
#  ['love', 'love', 'last', 'today', 'someone', 'grab'],
#  ['think',
#   'would',
#   'okay',
#   'didnt',
#   'observatory',
#   'like',
#   'light',
#   'observatory',
#   'elevator'],
#  ['think', 'place', 'best', 'condition', 'place', 'full', 'view'],
#  ['couldnt',
#   'find',
#   'lock',
#   'leave',
#   'years',
#   'road',
#   'namsan',
#   'tower',
#   'almost',
#   'flat',
#   'convenient',
#   'corona',
#   'virus',
#   'almost',
#   'number',
#   'tourists',
#   'increase',
#   'cable',
#   'also',
#   'operation'],
#  ['excellent', 'panoramic', 'view'],
#  ['night',
#   'view',
#   'high',
#   'place',
#   'great',
#   'inconvenience',
#   'overall',
#   'facilities',
#   'operation'],
#  ['observation',
#   'deck',
#   'nothing',
#   'special',
#   'rather',
#   'delicious',
#   'food',
#   'restaurant',
#   'second',
#   'floor'],
#  ['namsan',
#   'tower',
#   'neymar',
#   'also',
#   'visit',
#   'landmarks',
#   'city',
#   'glance',
#   'food'],
#  ['tower',
#   'jazz',
#   'really',
#   'good',
#   'keep',
#   'watch',
#   'sunset',
#   'night',
#   'view',
#   'felt',
#   'famous',
#   'place',
#   'however',
#   'interval',
#   'shuttle',
#   'tower',
#   'long'],
#  ['come',
#   'winter',
#   'dont',
#   'recommendation',
#   'wind',
#   'sooooo',
#   'definitely',
#   'come',
#   'next',
#   'year'],
#  ['place', 'night', 'view'],
#  ['like', 'light', 'show', 'require', 'extra', 'tower'],
#  ['beautiful', 'experience'],
#  ['like', 'place', 'south', 'wonder'],
#  ['every', 'step', 'take', 'wont', 'byebye'],
#  ['view', 'tower', 'daily', 'walk', 'course', 'really', 'good'],
#  ['tower',
#   'ticket',
#   'discount',
#   'today',
#   'couldnt',
#   'home',
#   'promise',
#   'next',
#   'take',
#   'cable'],
#  ['tower',
#   'extremely',
#   'beautiful',
#   'almost',
#   'store',
#   'close',
#   'couldnt',
#   'find',
#   'bottle',
#   'water',
#   'anywhere',
#   'back',
#   'mountain'],
#  ['excellent', 'view', 'city', 'early', 'pretty', 'busy', 'cable', 'unless'],
#  ['foot', 'good', 'walk', 'dont', 'tower', 'great', 'view'],
#  ['must',
#   'however',
#   'advise',
#   'first',
#   'days',
#   'trip',
#   'make',
#   'indeed',
#   'enjoyable',
#   'know',
#   'city',
#   'bite'],
#  ['representative', 'attractions', 'tower'],
#  ['well', 'little', 'bore'],
#  ['klook',
#   'queue',
#   'long',
#   'take',
#   'cable',
#   'station',
#   'take',
#   'hours',
#   'reach',
#   'would',
#   'choose',
#   'take'],
#  ['lookout',
#   'site',
#   'city',
#   'also',
#   'dont',
#   'miss',
#   'much',
#   'dont',
#   'tower',
#   'cost',
#   '19000',
#   'good',
#   'view',
#   'free',
#   'zone'],
#  ['visit', 'trek', 'convenient', 'take'],
#  ['great',
#   'place',
#   'view',
#   'night',
#   'view',
#   'beautiful',
#   'place',
#   'brazils',
#   'neymar',
#   'also',
#   'visit',
#   'recently'],
#  [],
#  ['good', 'walk', 'course', 'tire', 'take'],
#  ['worth', 'whole', 'view', 'vibrate', 'little', 'make', 'noise'],
#  ['amaze', 'view'],
#  ['trek',
#   'host',
#   'sport',
#   'council',
#   '62km',
#   'trek',
#   'jangchungdan',
#   'park',
#   'tower',
#   'fulfil',
#   'proud',
#   'time'],
#  ['tower',
#   'great',
#   'view',
#   'city',
#   'great',
#   'unfortunately',
#   'corona',
#   'also',
#   'leave',
#   'mark',
#   'shop',
#   'shop',
#   'center',
#   'empty'],
#  ['also', 'enjoy', 'performance', 'host', 'metropolitan', 'government'],
#  ['sweeter',
#   'accessible',
#   'lotte',
#   'world',
#   'tower',
#   'even',
#   'brazilian',
#   'national',
#   'football',
#   'team',
#   'represent'],
#  ['experience', 'town', 'personbring', 'comfywalking', 'shoe'],
#  ['good', 'walk', 'downtown', 'time', 'time'],
#  ['place', 'know', 'strange', 'place', 'better', 'expect', 'view', 'namsan'],
#  ['take',
#   'circular',
#   'climb',
#   'feel',
#   'look',
#   'east',
#   'come',
#   'crash',
#   'like',
#   'wave'],
#  ['beautiful', 'placei', 'love'],
#  ['beautiful', 'make', 'wonderful', 'impression'],
#  ['stun',
#   'view',
#   'nice',
#   'area',
#   'wander',
#   'around',
#   'like',
#   'duck',
#   'statues',
#   'padlock',
#   'place',
#   'toilets',
#   'worth',
#   'note',
#   'offer',
#   'cash',
#   'instead',
#   'card',
#   'part',
#   'hill',
#   'short',
#   'walk',
#   'catch',
#   'cable',
#   'back',
#   'extra'],
#  ['take',
#   'train',
#   'still',
#   'failry',
#   'decent',
#   'uphill',
#   'walk',
#   'involve',
#   'greenery',
#   'view',
#   'worth',
#   'awesome',
#   'city',
#   'look',
#   'would',
#   'recommend',
#   'lotte',
#   'world',
#   'tower',
#   'offer',
#   'jawdropping',
#   'vistas',
#   'even',
#   'lotte',
#   'world',
#   'view',
#   'point',
#   'higher'],
#  ['good',
#   'experience',
#   'good',
#   'view',
#   'however',
#   'clear',
#   'could',
#   'different',
#   'rainy',
#   'lift',
#   'bite',
#   'tacky',
#   'overall',
#   'would',
#   'reccomend',
#   'view'],
#  ['tower',
#   'really',
#   'difficult',
#   'access',
#   'walk',
#   'even',
#   'hike',
#   'nice',
#   'walk'],
#  ['nice',
#   'place',
#   'walk',
#   'beautiful',
#   'view',
#   'husband',
#   'walk',
#   'since',
#   'love',
#   'hike',
#   'also',
#   'decide',
#   'cable',
#   'also',
#   'film',
#   'kind',
#   'kdrama',
#   'quiet',
#   'also',
#   'call',
#   'dealightme',
#   'discount',
#   'tower',
#   'entrance',
#   'sure',
#   'would',
#   'great',
#   'experience',
#   'beautiful',
#   'sight',
#   'whole',
#   'city',
#   'lastly',
#   'dont',
#   'forget',
#   'leave',
#   'lock',
#   'love',
#   'youre',
#   'significant'],
#  ['tower',
#   'experience',
#   'unforgettable',
#   'well',
#   'place',
#   'make',
#   'remember',
#   'scenes',
#   'dramas',
#   'think',
#   'favorite',
#   'artists',
#   'record',
#   'place',
#   'fill',
#   'emotion',
#   'enjoy',
#   'route',
#   'well',
#   'dream',
#   'make',
#   'reality',
#   'place',
#   'beautiful',
#   'view',
#   'great',
#   'paradisethough',
#   'disadvantage',
#   'place',
#   'light',
#   'business',
#   'talls',
#   'hinder',
#   'vision',
#   'outside',
#   'best',
#   'definitely',
#   'recommend',
#   'tower'],
#  ['view',
#   'things',
#   'always',
#   'miss',
#   'would',
#   'highly',
#   'recommend',
#   'come',
#   'cable',
#   'come',
#   'arrive',
#   'sunset',
#   'view',
#   'nice',
#   'slightly',
#   'cloudy',
#   'turn',
#   'night',
#   'view',
#   'spectacular',
#   'ticket',
#   'tower',
#   'drink',
#   'bite',
#   'browse',
#   'shop',
#   'soak',
#   'atmosphere',
#   'lower',
#   'grind',
#   'section',
#   'lovely',
#   'light',
#   'great',
#   'vibe',
#   'chilly',
#   'take',
#   'light',
#   'throw',
#   'purchase',
#   'ticket',
#   'head',
#   'pretty',
#   'quick',
#   'enclose',
#   'night',
#   'view',
#   'stun',
#   'seat',
#   'lucky',
#   'enough',
#   'plus',
#   'place',
#   'purchase',
#   'drink',
#   'sweets',
#   'souvenirs',
#   'things',
#   'busy',
#   'strangely',
#   'children',
#   'clean',
#   'toilets',
#   'well',
#   'wait',
#   'lift',
#   'back',
#   'take',
#   'bite',
#   'longer',
#   'still',
#   'quick',
#   'nice',
#   'would',
#   'like',
#   'less',
#   'busier',
#   'could',
#   'really',
#   'soak',
#   'enjoy',
#   'view',
#   'weekend',
#   'still',
#   'enjoy',
#   'would',
#   'recommend',
#   'sure',
#   'staff',
#   'friendliest',
#   'scar',
#   'heights'],
#  ['tower',
#   'amaze',
#   'place',
#   'beautiful',
#   'view',
#   'seulyou',
#   'leave',
#   'love',
#   'lock',
#   'take',
#   'beautiful',
#   'photos',
#   'amaze',
#   'background',
#   'recommend',
#   'goin',
#   'afternom',
#   'eveningyou',
#   'enjoy',
#   'view',
#   'city',
#   'people',
#   'affordable',
#   'price',
#   'cost',
#   'around',
#   '9500',
#   'adults',
#   '6500',
#   'children',
#   'tower',
#   'abservatory',
#   'unique',
#   'extraordinary',
#   'experience',
#   'really',
#   'beutiful',
#   'place',
#   'people',
#   'many',
#   'countries',
#   'tower',
#   'first',
#   'place'],
#  ['nice',
#   'view',
#   'though',
#   'filthy',
#   'windows',
#   'sunset',
#   'pack',
#   'stuffy',
#   'want',
#   'avoid',
#   'covid',
#   'heck',
#   'work',
#   'mins',
#   'better',
#   'lotte',
#   'world',
#   'tower'],
#  ['hike',
#   'stairs',
#   'path',
#   'road',
#   'path',
#   'think',
#   'next',
#   'time',
#   'stick',
#   'road',
#   'side',
#   'stairs',
#   'hard',
#   'climbat',
#   'least',
#   'still',
#   'proud',
#   'view',
#   'cant',
#   'beat',
#   'amaze',
#   'fall',
#   'colorful',
#   'tree',
#   'beauty',
#   'journey'],
#  ['visit',
#   'couple',
#   'time',
#   'experience',
#   'amazingly',
#   'great',
#   'highly',
#   'recommend',
#   'like',
#   'walk',
#   'enjoy',
#   'opportunity',
#   'greater'],
#  ['visit',
#   'tower',
#   'summer',
#   '2020',
#   'pleasantly',
#   'even',
#   'enjoyable',
#   'think',
#   'would',
#   'sure',
#   'wear',
#   'walk',
#   'comfortable',
#   'shoe',
#   'trolley',
#   'give',
#   'lovely',
#   'night',
#   'time',
#   'view',
#   'theres',
#   'love',
#   'locket',
#   'bridge',
#   'special',
#   'either',
#   'bring',
#   'lock',
#   'purchase',
#   'lock',
#   'little',
#   'store',
#   'attache',
#   'bridge',
#   'rail',
#   'certain',
#   'area',
#   'also',
#   'sign',
#   'bench',
#   'novelty',
#   'items',
#   'youll',
#   'know',
#   'spot',
#   'elevator',
#   'tower',
#   'super',
#   'fast',
#   'little',
#   'room',
#   'view',
#   'spot',
#   'tower',
#   'delightful',
#   'offer',
#   'opportunities',
#   'selfies',
#   'pics',
#   'enjoy',
#   'great',
#   'view',
#   'observation',
#   'tower',
#   'portion',
#   'glass',
#   'floor',
#   'actually',
#   'find',
#   'really',
#   'great',
#   'gift',
#   'bring',
#   'home',
#   'didnt',
#   'travel',
#   'overall',
#   'enjoyable',
#   'experience',
#   'plenty',
#   'taxis',
#   'outside',
#   'beware',
#   'dont',
#   'want',
#   'travel',
#   'radius',
#   'might',
#   'check',
#   'find',
#   'back',
#   'hotel',
#   'depend',
#   'stay',
#   'also',
#   'know',
#   'general',
#   'traffic',
#   'horrible',
#   'take',
#   'long',
#   'spot',
#   'another',
#   'plan',
#   'make',
#   'plan'],
#  ['skyrail',
#   'cable',
#   'save',
#   'time',
#   'energy',
#   'climb',
#   'tower',
#   'foot',
#   'youll',
#   'timeenergy',
#   'explore',
#   'worth',
#   'person',
#   'suggest',
#   'bring',
#   'lock',
#   'home',
#   'initial',
#   'youll',
#   'unique',
#   'lock',
#   'thatll',
#   'stick',
#   'lock',
#   'sell',
#   'breathtaking',
#   'view'],
#  ['view',
#   'amaze',
#   'also',
#   'really',
#   'recommend',
#   'walk',
#   'hill',
#   'instead',
#   'cable',
#   'long',
#   'climb',
#   'worth',
#   'especially',
#   'sunset',
#   'youll',
#   'also',
#   'skip',
#   'long',
#   'cable',
#   'queue'],
#  ['walk',
#   'hotel',
#   'nice',
#   'walk',
#   'last',
#   'bite',
#   'forest',
#   'tower',
#   'plaza',
#   'deck',
#   'view',
#   'deck',
#   'cover',
#   'american',
#   'halloween',
#   'music',
#   'like',
#   'monster',
#   'mash',
#   'cute',
#   'first',
#   'minutes',
#   'away',
#   'music',
#   'gift',
#   'shop',
#   'whole',
#   'place',
#   'minus',
#   'restaurants',
#   'escape',
#   'music',
#   'great',
#   'view',
#   'tower',
#   'though'],
#  ['namsan',
#   'tower',
#   'tower',
#   'radio',
#   'tower',
#   'popular',
#   'tourist',
#   'spot',
#   'heart',
#   'close',
#   'myeongdong',
#   'locate',
#   'mountain',
#   'accessible',
#   'roadcable',
#   'cara',
#   'hike',
#   'prefer',
#   'even',
#   'catch',
#   'glimpse',
#   'sunset',
#   'night',
#   'time',
#   'however',
#   'crowd',
#   'board',
#   'cable',
#   'would',
#   'long',
#   'wait',
#   'whole',
#   'love',
#   'padlock',
#   'rail',
#   'mind',
#   'blow',
#   'lock',
#   'years',
#   'together',
#   'people',
#   'struggle',
#   'pose',
#   'snap',
#   'whole',
#   'tower',
#   'picture',
#   'watch',
#   'view',
#   'point',
#   'photoopusual',
#   'convenience',
#   'storessnack',
#   'barsrestroomssouvenir',
#   'shop',
#   'available'],
#  ['great',
#   'view',
#   'power',
#   'walk',
#   'namsan',
#   'park',
#   'love',
#   'view',
#   'city',
#   'directions',
#   'gorge',
#   'gummy',
#   'candy',
#   'candy',
#   'store'],
#  ['place',
#   'degree',
#   'seoulbest',
#   'time',
#   'afternoon',
#   'night',
#   'light',
#   'night'],
#  ['namsan',
#   'first',
#   'golden',
#   'hour',
#   'catch',
#   'winter',
#   'bath',
#   'golden',
#   'really',
#   'worthy',
#   'namsan',
#   'tower',
#   'breeze',
#   'wind',
#   'winter',
#   'chocolate',
#   'enough',
#   'keep',
#   'warm'],
#  ['tower',
#   'view',
#   'fantastic',
#   'city',
#   'light',
#   'nice',
#   'even',
#   'also',
#   'restaurant',
#   'case',
#   'hungry',
#   'want',
#   'enjoy',
#   'view'],
#  ['tower',
#   'relatively',
#   'easy',
#   'trainbus',
#   'take',
#   'special',
#   'hill',
#   'hike',
#   'hill',
#   'good',
#   'workout',
#   'tower',
#   'even',
#   'view',
#   'city',
#   'fantastic',
#   'also',
#   'couple',
#   'gift',
#   'shop',
#   'purchase',
#   'souvenirs',
#   'must',
#   'take',
#   'tram',
#   'ride',
#   'elevator',
#   'base',
#   'tower',
#   'youre',
#   'hike'],
#  ['well',
#   'worth',
#   'time',
#   'offer',
#   'great',
#   'view',
#   'city',
#   'plenty',
#   'merch',
#   'hungry',
#   'restaurants',
#   'well',
#   'winter',
#   'dress',
#   'warm',
#   'since',
#   'could',
#   'pretty',
#   'windy',
#   'easy',
#   'entrence',
#   'pretty',
#   'cheap'],
#  ['arrive',
#   'luggage',
#   'hotel',
#   'straight',
#   'away',
#   'take',
#   'namsan',
#   'tower',
#   'book',
#   'ticket',
#   'klook',
#   'scan',
#   'ticket',
#   'entrance',
#   'view',
#   'night',
#   'amaze',
#   'whole',
#   'area',
#   'strong',
#   'legs',
#   'walk',
#   'hill'],
#  ['locate',
#   'relatively',
#   'central',
#   'location',
#   'seoulno',
#   'direct',
#   'metro',
#   'easily',
#   'navigate',
#   'alight',
#   'dongguk',
#   'university',
#   'exit',
#   'stop',
#   'near',
#   'bridge',
#   'take',
#   'reach',
#   'tower',
#   'locate',
#   'namsan',
#   'mountain',
#   'whereby',
#   'take',
#   'many',
#   'nice',
#   'photos',
#   'tower',
#   'rather',
#   'optional',
#   'mountain',
#   'already',
#   'provide',
#   'fantastic',
#   'view',
#   'city',
#   'defo',
#   'worth'],
#  ['purchase',
#   'skip',
#   'line',
#   'ticket',
#   'time',
#   'actually',
#   'middle',
#   'week',
#   'january',
#   'didnt',
#   'need',
#   'however',
#   'seem',
#   'like',
#   'review',
#   'still',
#   'want',
#   'consider',
#   'take',
#   'palace',
#   'route',
#   'tower',
#   'still',
#   'quite',
#   'hike',
#   'hill',
#   'view',
#   'really',
#   'incredible',
#   'lucky',
#   'weather',
#   'cooperate',
#   'glare',
#   'windows',
#   'bite',
#   'haze',
#   'think',
#   'photos',
#   'come',
#   'okay',
#   'good',
#   'time',
#   'walk',
#   'around',
#   'floor',
#   'look',
#   'different',
#   'point',
#   'around',
#   'city',
#   'helpful',
#   'signage',
#   'distance',
#   'different',
#   'cities',
#   'small',
#   'gift',
#   'shop',
#   'postcards',
#   'even',
#   'mail',
#   'restaurant',
#   'believe',
#   'need',
#   'reservations',
#   'tower',
#   'restaurants',
#   'souvenir',
#   'shop',
#   'wish',
#   'would',
#   'take',
#   'cable',
#   'sound',
#   'like'],
#  ['sure',
#   'sucker',
#   'tower',
#   'tall',
#   'build',
#   'donno',
#   'nseoul',
#   'tower',
#   'best121',
#   'floor',
#   'high',
#   'guess',
#   'glass',
#   'bottom',
#   'photo',
#   'opswe',
#   'good',
#   'time'],
#  ['visit',
#   'weekday',
#   'avoid',
#   'long',
#   'line',
#   'cable',
#   'skip',
#   'ticket',
#   'line',
#   'purchase',
#   'thru',
#   'klook',
#   'view',
#   'much',
#   'nicer',
#   'autumn'],
#  ['pretty',
#   'nice',
#   'place',
#   'enjoy',
#   'hike',
#   'tower',
#   'great',
#   'picture',
#   'really',
#   'worth',
#   'money',
#   'tower'],
#  ['myeongdong',
#   'walk',
#   'uphil',
#   'cable',
#   'station',
#   'afternoon',
#   'arrive',
#   'station',
#   'need',
#   'wait',
#   'line',
#   'around',
#   'minutes',
#   'quite',
#   'waste',
#   'time',
#   'consider',
#   'cable',
#   'ride',
#   'minutes',
#   'since',
#   'already',
#   'observatory',
#   'tower',
#   'ticket',
#   'klook',
#   'directly',
#   'however',
#   'surprise',
#   'view',
#   'deck',
#   'special',
#   'worth',
#   'cost',
#   'better',
#   'view',
#   'without',
#   'observatory',
#   'tower',
#   'spend',
#   'time',
#   'lock',
#   'love',
#   'area',
#   'cute',
#   'shuttle',
#   'myeongdong',
#   'cheaper',
#   'time',
#   'save',
#   'compare',
#   'take',
#   'line',
#   'cable'],
#  ['super',
#   'awesome',
#   'place',
#   'really',
#   'love',
#   'everything',
#   'would',
#   'like',
#   'back',
#   'super',
#   'worth'],
#  ['decide',
#   'despite',
#   'weather',
#   'people',
#   'local',
#   'foreigners',
#   'imagine',
#   'spectacular',
#   'would',
#   'clear'],
#  ['mind',
#   'spend',
#   'money',
#   'cable',
#   'ride',
#   'ticket',
#   'view',
#   'absolutely',
#   'worth',
#   'cost',
#   'coffee',
#   'shop',
#   'amaze',
#   'desserts',
#   'stoolstables',
#   'snack',
#   'degree',
#   'view',
#   'amaze',
#   'elevators',
#   'move',
#   'quickly',
#   'bathroom',
#   'quite',
#   'view',
#   'seriously'],
#  ['locate',
#   'namsan',
#   'mountain',
#   'central',
#   'easy',
#   'dusk',
#   'provide',
#   'breathtaking',
#   'view',
#   'need',
#   'take',
#   'cable',
#   'plaza',
#   'area',
#   'find',
#   'attraction',
#   'like',
#   'love',
#   'lock',
#   'something',
#   'similar',
#   'paris',
#   'wish',
#   'pond',
#   'various',
#   'observatory',
#   'deck',
#   'food',
#   'court',
#   'museums',
#   'entrance',
#   'observatory',
#   'tower',
#   'boast',
#   'panoramic',
#   'view',
#   'city',
#   'seouls',
#   'must',
#   'attractions'],
#  ['namsan',
#   'tower',
#   'know',
#   'many',
#   'things',
#   'cable',
#   'ride',
#   'nice',
#   'trek',
#   'namsan',
#   'park',
#   'great',
#   'aerial',
#   'view',
#   'city',
#   'museums',
#   'cafe',
#   'height',
#   'almost',
#   '240m',
#   'tower',
#   'onservatory',
#   'deck',
#   'offer',
#   'amaze',
#   'view',
#   'city',
#   'iconic',
#   'letter',
#   'result',
#   'remodel',
#   'tower',
#   '2005',
#   'since',
#   'place',
#   'know',
#   'tower',
#   'beautiful',
#   'bright',
#   'light',
#   'night'],
#  ['family',
#   'vacation',
#   'years',
#   'stay',
#   'millenium',
#   'hilton',
#   'front',
#   'station',
#   'didnt',
#   'know',
#   'years',
#   'countdown',
#   'decide',
#   'climb',
#   'mountain',
#   'directly',
#   'front',
#   'millenium',
#   'hilton',
#   'summit',
#   'tower',
#   'years',
#   'fireworks',
#   'temperature',
#   'minus',
#   'degrees',
#   'celsius',
#   'bundle',
#   'around',
#   'start',
#   'hike',
#   'lovely',
#   'hike',
#   'beautiful',
#   'view',
#   'city',
#   'night',
#   'hard',
#   'hike',
#   'installations',
#   'along',
#   'include',
#   'strange',
#   'love',
#   'heart',
#   'lock',
#   'installation',
#   'apparently',
#   'love',
#   'heart',
#   'lockets',
#   'write',
#   'message',
#   'lock',
#   'around',
#   'fence',
#   'installations',
#   'along',
#   'mountain',
#   'mountain',
#   'cafes',
#   'gift',
#   'shop',
#   'purchase',
#   'ticket',
#   'tower',
#   'instead',
#   'chocolate',
#   'coffees',
#   'celebrate',
#   '2020',
#   'watch',
#   'fireworks',
#   'fireworks',
#   'small',
#   'vantage',
#   'point',
#   'impressive',
#   'overall',
#   'beautiful',
#   'hike',
#   'absolutely',
#   'fantastic',
#   'ring',
#   'year',
#   'start',
#   'snow',
#   'along',
#   'well',
#   'make',
#   'romantic',
#   'special',
#   'teenage',
#   'daughter',
#   'take',
#   'many',
#   'picture',
#   'walk',
#   'around',
#   'drink',
#   'look',
#   'around',
#   'gift',
#   'shop',
#   'make',
#   'back',
#   'start',
#   'chill',
#   'highly',
#   'recommend',
#   'hike',
#   'could',
#   'imagine',
#   'better',
#   'years',
#   'perfect'],
#  ['gorgeous',
#   'view',
#   'night',
#   'tower',
#   'didnt',
#   'realize',
#   'hillmountain',
#   'surprise',
#   'didnt',
#   'walk',
#   'thankful',
#   'make',
#   'windy',
#   'roads',
#   'walk',
#   'wasnt',
#   'happen',
#   'definitely',
#   'worth',
#   'trip',
#   'love',
#   'whole',
#   'experience',
#   'would',
#   'definitely',
#   'next',
#   'time',
#   'come',
#   'maybe',
#   'next',
#   'time'],
#  ['price',
#   'ticket',
#   'bite',
#   'expensive',
#   'consider',
#   'surround',
#   'attractions',
#   'significantly',
#   'cheaper',
#   'enjoy',
#   'view',
#   'though',
#   'many',
#   'opportunities',
#   'grab',
#   'souvenir',
#   'would',
#   'definitely',
#   'come',
#   'back',
#   'different',
#   'season',
#   'view',
#   'would',
#   'look',
#   'spring',
#   'summer'],
#  ['really',
#   'amaze',
#   'view',
#   'night',
#   'although',
#   'nice',
#   'place',
#   'recreation',
#   'young',
#   'ones',
#   'alot',
#   'food'],
#  ['great',
#   'view',
#   'city',
#   'bite',
#   'hard',
#   'walk',
#   'closer',
#   'tower',
#   'view',
#   'outside',
#   'actually',
#   'picture',
#   'worthy',
#   'love',
#   'sweet',
#   'post',
#   'card',
#   'mail',
#   'service',
#   'best',
#   'souvenir',
#   'ever',
#   'send',
#   'card',
#   'atop',
#   'tower',
#   'family',
#   'across',
#   'world',
#   'like',
#   'walk',
#   'around',
#   'different',
#   'lower',
#   'level',
#   'cool',
#   'statues',
#   'giftshops',
#   'food',
#   'place'],
#  ['open',
#   'public',
#   '1980',
#   'provide',
#   'radio',
#   'broadcast',
#   'also',
#   'tourist',
#   'purpose',
#   'nice',
#   'great',
#   'view',
#   'observation',
#   'tower',
#   'locate',
#   'namsan',
#   'mountain',
#   'stand',
#   'meter',
#   'level',
#   'visible',
#   'part'],
#  ['tower',
#   'rain',
#   'mean',
#   'clear',
#   'absolutely',
#   'stun',
#   'view',
#   'round',
#   'especially',
#   'mountains',
#   'north',
#   'imagine',
#   'later',
#   'week',
#   'smog',
#   'start',
#   'creep',
#   'back',
#   'view',
#   'could',
#   'quite',
#   'disappoint',
#   'also',
#   'reasonably',
#   'price',
#   'gift',
#   'shop',
#   'actually',
#   'good',
#   'quality',
#   'items',
#   'nice',
#   'surprise',
#   'knock',
#   'star',
#   'little',
#   'cable',
#   'take',
#   'base',
#   'tower',
#   'bottom',
#   'hill',
#   'work',
#   'take',
#   'stairs',
#   'issue',
#   'mobility',
#   'problems',
#   'would',
#   'stick'],
#  ['lead',
#   'tunnel',
#   'love',
#   'lock',
#   'area',
#   'also',
#   'observatory',
#   'deck',
#   'best',
#   'lover',
#   'easy',
#   'cable'],
#  ['beautiful',
#   'clean',
#   'inside',
#   'alot',
#   'history',
#   'show',
#   'throughout',
#   'area',
#   'towerthe',
#   'ride',
#   'elevator',
#   'beautiful',
#   'look',
#   'inside',
#   'elevator'],
#  ['well',
#   'worth',
#   'trip',
#   'tower',
#   'great',
#   'view',
#   'cable',
#   'tower',
#   'tower'],
#  ['tower',
#   'interest',
#   'probably',
#   'worth',
#   'visit',
#   'unless',
#   'nice',
#   'clear',
#   'dull',
#   'couldnt',
#   'much'],
#  ['highly',
#   'recommend',
#   'take',
#   'trip',
#   'night',
#   'hours',
#   'actually',
#   'city',
#   'light',
#   'would',
#   'highly',
#   'recommend',
#   'spend',
#   'extra',
#   'money',
#   'skip',
#   'line',
#   'busy',
#   'purchase',
#   'lock',
#   'place',
#   'wherever',
#   'would',
#   'like',
#   'cooler',
#   'outside',
#   'dress',
#   'warm',
#   'cold'],
#  ['nice',
#   'view',
#   'around',
#   'city',
#   'local',
#   'customs',
#   'attractive',
#   'part',
#   'place',
#   'dont',
#   'forget'],
#  ['climb',
#   'little',
#   'mountain',
#   'tower',
#   'locate',
#   'nearby',
#   'right',
#   'heart',
#   'city',
#   'enjoy',
#   'view',
#   'amaze'],
#  ['firstly',
#   'trust',
#   'google',
#   'direction',
#   'tower',
#   'require',
#   'alight',
#   'quiet',
#   'stop',
#   'walk',
#   'aong',
#   'walk',
#   'hill',
#   'follow',
#   'directions',
#   'website',
#   'reliable',
#   'tower',
#   'deck',
#   'provide',
#   'typical',
#   'city',
#   'view',
#   'must',
#   'tower',
#   'provide',
#   'check',
#   'toilets',
#   'place',
#   'relieve',
#   'admire',
#   'city',
#   'view'],
#  ['short',
#   'period',
#   'time',
#   'sure',
#   'definitely',
#   'make',
#   'tower',
#   'myeongdong',
#   'walk',
#   'cable',
#   'ride',
#   'view',
#   'amaze'],
#  ['quite',
#   'ride',
#   'tower',
#   'stun',
#   'view',
#   'adjoin',
#   'hello',
#   'kitty',
#   'museum',
#   'ryans',
#   'cheezball',
#   'adventure',
#   'worth',
#   'effort',
#   'around',
#   'view',
#   'tower',
#   'also',
#   'tell',
#   'direction',
#   'country',
#   'spot',
#   'distance',
#   'even',
#   'beautifully',
#   'spend'],
#  ['nice',
#   'efficient',
#   'ticket',
#   'quick',
#   'lift',
#   'digital',
#   'visuals',
#   'tower',
#   'departure',
#   'area',
#   'good',
#   'best',
#   'really',
#   'queue',
#   'back',
#   'good',
#   'view',
#   'city'],
#  ['visit',
#   'observatory',
#   'cable',
#   'cable',
#   'short',
#   'walk',
#   'myeongdong',
#   'train',
#   'station',
#   'cable',
#   'bring',
#   'walkway',
#   'lock',
#   'continue',
#   'tower',
#   'night',
#   'bright',
#   'light',
#   'well',
#   'numerous',
#   'vehicles',
#   'come',
#   'retail',
#   'ding',
#   'establishments',
#   'retail',
#   'area',
#   'tower'],
#  ['ticket',
#   'couple',
#   'adult',
#   'free',
#   'popcorn',
#   'nice',
#   'view',
#   'reach',
#   'view',
#   'floor'],
#  ['quite',
#   'hard',
#   'lose',
#   'thrice',
#   'waze',
#   'mess',
#   'guide',
#   'find',
#   'different',
#   'route',
#   'though',
#   'book',
#   'online',
#   'ticket',
#   'take',
#   'cable',
#   'cars',
#   'cute',
#   'area',
#   'love',
#   'lock',
#   'view',
#   'city',
#   'beautiful',
#   'sunny',
#   'windy',
#   'though',
#   'altogether',
#   'nice',
#   'experience'],
#  ['tower',
#   'place',
#   'observe',
#   'city',
#   'choose',
#   'walk',
#   'park',
#   'take',
#   'cable',
#   'canke',
#   'cost',
#   '7000\\',
#   '10000\\',
#   'return'],
#  ['probably',
#   'outshine',
#   'lotte',
#   'tower',
#   'course',
#   'bigger',
#   'badder',
#   'wait',
#   'time',
#   'surround',
#   'area',
#   'tower',
#   'much',
#   'better',
#   'good',
#   'food',
#   'lovelocks',
#   'trippy',
#   'color',
#   'room',
#   'enter',
#   'tower',
#   'elevator'],
#  ['didnt',
#   'actual',
#   'tower',
#   'ride',
#   'lock',
#   'lock',
#   'wall',
#   'bring',
#   'definetly',
#   'overprised',
#   'dont',
#   'forget',
#   'none',
#   'view',
#   'pleasant',
#   'price',
#   'fine'],
#  ['plan',
#   'observatory',
#   'mind',
#   'weather',
#   'condition',
#   'notice',
#   'visibility',
#   'offer',
#   'give',
#   'refund',
#   'make',
#   'valid',
#   'another',
#   'disappoint'],
#  ['amaze',
#   'view',
#   'trek',
#   '15km',
#   'love',
#   'lock',
#   'area',
#   'mountain',
#   'tower',
#   'awesome',
#   'view',
#   'beautiful',
#   'clear'],
#  ['overall',
#   'excellent',
#   'experience',
#   'dont',
#   'drive',
#   'unless',
#   'know',
#   'navi',
#   'apps',
#   'dont',
#   'quite',
#   'work',
#   'taxi',
#   'take',
#   'second',
#   'attempt',
#   'long',
#   'walk',
#   'tower',
#   'gondola',
#   'option',
#   'food',
#   'souvenir',
#   'shop',
#   'options',
#   'wait',
#   'minutes',
#   'queue',
#   'quite',
#   'large',
#   'though',
#   'view',
#   'amaze',
#   'night',
#   'best',
#   'experience',
#   'others',
#   'scenic',
#   'spot',
#   'grind',
#   'trail'],
#  ['tall',
#   'tower',
#   'light',
#   'ignite',
#   'beautiful',
#   'hill',
#   'call',
#   'towernamsan',
#   'tower',
#   'astonish',
#   'beauty',
#   'namsan',
#   'mountain',
#   'flourish',
#   'locals',
#   'foreigners',
#   'alike',
#   'place',
#   'love',
#   'cupids',
#   'make',
#   'wish',
#   'lock',
#   'love',
#   'lock',
#   'symbolize',
#   'eternity',
#   'true',
#   'love',
#   'find',
#   'love',
#   'life',
# ...
#   'bucket',
#   'coke',
#   'combo',
#   'ticket',
#   'lift',
#   'tell',
#   'look',
#   'ceiling',
#   'lift',
#   'watch',
#   'retro',
#   'second',
#   'clip',
#   'tower',
#   'explode',
#   'space',
#   'land',
#   'somewhere',
#   'step',
#   'lift',
#   'around',
#   'corner',
#   'stand',
#   'another',
#   'photo',
#   'front',
#   'green',
#   'screen',
#   'stand',
#   'line',
#   'photo',
#   'different',
#   'sceneries',
#   'without',
#   'tower',
#   'need',
#   '12000won',
#   'photo',
#   'frame',
#   'photo',
#   'bypass',
#   'congratulations',
#   'tower',
#   'multiple',
#   'sign',
#   'photos',
#   'allow',
#   'stepsplatforms',
#   'expensive',
#   'souvenirs',
#   'weight',
#   'self',
#   'fill',
#   'select',
#   'candy',
#   'sight',
#   'nice',
#   'personally',
#   'park',
#   'around',
#   'give',
#   'nicer',
#   'view',
#   'without',
#   'money',
#   'grab'],
#  ['love',
#   'place',
#   'cable',
#   'hang',
#   'around',
#   'tower',
#   'park',
#   'free',
#   'performances',
#   'romantic',
#   'well'],
#  ['want', 'must', 'week', 'weekend', 'wasnt', 'queue'],
#  ['like',
#   'attractions',
#   'type',
#   'north',
#   'tower',
#   'tourist',
#   'trap',
#   'doesnt',
#   'mean',
#   'worth',
#   'aware',
#   'primarily',
#   'generate',
#   'revenue',
#   'group',
#   'photo',
#   'sales',
#   'overprice',
#   'gift',
#   'shop',
#   'restaurants',
#   'stick',
#   'enjoy',
#   'view',
#   'youll',
#   'save',
#   'word',
#   'wise',
#   'head',
#   'back',
#   'stop',
#   'make',
#   'sure',
#   'take',
#   'correct',
#   'path',
#   'otherwise',
#   'like',
#   'could',
#   'unwittingly',
#   'hike',
#   'full',
#   'length',
#   'wrong',
#   'side',
#   'mountain',
#   'happen',
#   'tramway',
#   'ticket',
#   'ride',
#   'back',
#   'base',
#   'tower',
#   'wont',
#   'make',
#   'mistake',
#   'twice'],
#  ['beautiful',
#   'view',
#   'lovely',
#   'area',
#   'sunset',
#   'tuesday',
#   'crazy',
#   'busy',
#   'spend',
#   'time',
#   'line',
#   'time',
#   'walk',
#   'hill',
#   'stairs',
#   'elevator',
#   'observatory',
#   'take',
#   'cable',
#   'well',
#   'still',
#   'walk'],
#  ['visit',
#   'friends',
#   'tower',
#   'centre',
#   'city',
#   'nice',
#   'degree',
#   'view',
#   'nice'],
#  ['ride',
#   'cable',
#   'tower',
#   'amaze',
#   'experience',
#   'stun',
#   'view',
#   'city',
#   'thousands',
#   'love',
#   'lock',
#   'sorrounded',
#   'place',
#   'place',
#   'love',
#   'lock',
#   'tower',
#   'important',
#   'landmarks',
#   'iconic',
#   'tower',
#   'frequent',
#   'tourist',
#   'spot',
#   'nowadays',
#   'must'],
#  ['easy', 'tower', 'peak', 'great', 'view', 'city', 'much', 'else'],
#  ['first',
#   'place',
#   'arrive',
#   'beautiful',
#   'night',
#   'tower',
#   'nothing',
#   'much',
#   'city',
#   'night',
#   'view',
#   'take',
#   'cable',
#   'hill',
#   'short',
#   'time',
#   'theres',
#   'free',
#   'shuttle',
#   'cable',
#   'entrance',
#   'need',
#   'first',
#   'write',
#   'shuttle',
#   'coincidence'],
#  ['tower',
#   'rainy',
#   'mist',
#   'didnt',
#   'tower',
#   'view',
#   'great',
#   'time',
#   'would',
#   'sunny',
#   'clear',
#   'night'],
#  ['tower',
#   'great',
#   'night',
#   'view',
#   'cable',
#   'cable',
#   'kinda',
#   'shaky',
#   'first',
#   'think',
#   'safe',
#   'attractions',
#   'tooteddy',
#   'bear',
#   'museum',
#   'marvel',
#   'museum',
#   'please',
#   'check',
#   'vlog',
#   'information',
#   'channel',
#   'search',
#   'title',
#   'travel',
#   'blog',
#   'jeju',
#   'namsan',
#   'tower'],
#  ['must',
#   'tower',
#   'certainly',
#   'great',
#   'view',
#   'especially',
#   'worth',
#   'close',
#   'sunset',
#   'many',
#   'light',
#   'supercity',
#   'come',
#   'pretty',
#   'crowd'],
#  ['memorable',
#   'literally',
#   'walk',
#   'hill',
#   'friend',
#   'package',
#   'ticket',
#   'popcorn',
#   'drink',
#   'worth',
#   'view',
#   'city',
#   'stun'],
#  ['catch',
#   'near',
#   'myeongdong',
#   'station',
#   'tower',
#   'bite',
#   'hilly',
#   'walk',
#   'still',
#   'require',
#   'inside',
#   'since',
#   'attractions',
#   'outside',
#   'enough',
#   'number',
#   'floor',
#   'free',
#   'outside',
#   'allow',
#   'free',
#   'hanbok',
#   'trial',
#   'also',
#   'show'],
#  ['tower',
#   'windows',
#   'quite',
#   'dirty',
#   'didnt',
#   'really',
#   'good',
#   'view',
#   'outdoor',
#   'view',
#   'definitely',
#   'much',
#   'better',
#   'many',
#   'restaurants',
#   'favourite',
#   'definitely',
#   'chicken',
#   'restaurantreally',
#   'good',
#   'spicy'],
#  ['place',
#   'place',
#   'want',
#   'stay',
#   'definitely',
#   'wasnt',
#   'disappointment',
#   'individual',
#   'option',
#   'take',
#   'hill',
#   'make',
#   'hike',
#   'mind',
#   'pretty',
#   'steep',
#   'long',
#   'hike',
#   'tower',
#   'seriously',
#   'dollars',
#   'definitely',
#   'purchase',
#   'lock',
#   'famous',
#   'fence',
#   'lock',
#   'cheesy',
#   'like',
#   'youre',
#   'kind',
#   'stuff',
#   'great',
#   'couple',
#   'tower',
#   'amaze',
#   'suggest',
#   'even',
#   'view',
#   'night',
#   'wont',
#   'disappoint'],
#  ['walk',
#   'base',
#   'tower',
#   'park',
#   'gondola',
#   'also',
#   'available',
#   'walk',
#   'maybe',
#   'minutes',
#   'good',
#   'exercise',
#   'nice',
#   'view',
#   'decent',
#   'elevator',
#   'experience',
#   'lotte',
#   'world',
#   'tower',
#   'much',
#   'better',
#   'though',
#   'almost',
#   'triple',
#   'price',
#   '27000',
#   'compare',
#   '10000'],
#  ['amaze',
#   'view',
#   'interest',
#   'pleasant',
#   'easy',
#   'reach',
#   'pleasant',
#   'walk',
#   'around',
#   'nice',
#   'souvenir',
#   'shop'],
#  ['place',
#   'must',
#   'tower',
#   'city',
#   'night',
#   'light',
#   'beatification',
#   'inspire',
#   'still',
#   'sight',
#   'sore',
#   'namsan',
#   'park',
#   'head',
#   'towards',
#   'cable',
#   'youre',
#   'half',
#   'park',
#   'bottom',
#   'tower',
#   'lovely',
#   'dont',
#   'want',
#   'tower',
#   'park',
#   'offer',
#   'three',
#   'stag',
#   'namsan',
#   'park',
#   'bottom',
#   'tower',
#   'wander',
#   'around',
#   'choose',
#   'range',
#   'restaurants',
#   'final',
#   'stage',
#   'shop',
#   'make',
#   'sure',
#   'head',
#   'clear'],
#  ['dinner',
#   'hancock',
#   'come',
#   'admission',
#   'view',
#   'deck',
#   'stay',
#   'till',
#   'plus',
#   'allow',
#   'enjoy',
#   'night',
#   'view',
#   'best',
#   'view',
#   'sunset',
#   'toilet',
#   'full',
#   'length',
#   'glass',
#   'window',
#   'offer',
#   'wonderful',
#   'view',
#   'leave',
#   'night',
#   'tower',
#   'beautifully',
#   'light',
#   'windy',
#   'weather',
#   'make',
#   'walk',
#   'area'],
#  ['tower',
#   'build',
#   'recently',
#   'give',
#   'fantastic',
#   'view',
#   'city',
#   'visit',
#   'tower',
#   'sunset',
#   'time',
#   'would',
#   'best',
#   'time',
#   'transition',
#   'daylight',
#   'night',
#   'city',
#   'light',
#   'beautiful'],
#  ['normal',
#   'observation',
#   'tower',
#   'passable',
#   'nothing',
#   'really',
#   'stand',
#   'compare',
#   'tower',
#   'cities',
#   'notice',
#   'quite',
#   'number',
#   'shop',
#   'observation',
#   'deck',
#   'sell',
#   'souvenirs',
#   'sweets',
#   'popcorn',
#   'area',
#   'bottom',
#   'tower',
#   'actually',
#   'interest',
#   'love',
#   'lock',
#   'cafes',
#   'unique',
#   'shop',
#   'area',
#   'empty',
#   'space',
#   'performances'],
#  ['much',
#   'better',
#   'idea',
#   'hike',
#   'look',
#   'around',
#   'area',
#   'take',
#   'spend',
#   'money',
#   'ways',
#   'much',
#   'better',
#   'view'],
#  ['cable',
#   'ride',
#   'tower',
#   'station',
#   'cable',
#   'squeezy',
#   'full',
#   'space',
#   'take',
#   'picture',
#   'wonder',
#   'whats',
#   'capacity',
#   'combo',
#   'come',
#   'popcorn',
#   'choose',
#   'within',
#   'flavour',
#   'soda',
#   'drink',
#   'proceed',
#   'photo',
#   'take',
#   'station',
#   'staff',
#   'rush',
#   'crowd',
#   'lift',
#   'observation',
#   'deck',
#   'deck',
#   'reasonably',
#   'space',
#   'folks',
#   'rest',
#   'area',
#   'wait',
#   'nightfall',
#   'night',
#   'view',
#   'staff',
#   'talk',
#   'within',
#   'probably',
#   'joke',
#   'staff',
#   'snack',
#   'away',
#   'candy',
#   'weeny',
#   'beeny',
#   'well',
#   'view',
#   'beautiful',
#   'probably',
#   'staff',
#   'need',
#   'motivation',
#   'make',
#   'tourist',
#   'memorable',
#   'moment',
#   'definitely',
#   'great',
#   'view'],
#  ['degree',
#   'view',
#   'busy',
#   'worth',
#   'plenty',
#   'shop',
#   'survey',
#   'cable',
#   'take',
#   'almost',
#   'base',
#   'tower',
#   'catch'],
#  ['soul',
#   'city',
#   'last',
#   'week',
#   'days',
#   'hotel',
#   'direct',
#   'view',
#   'north',
#   'tower',
#   'namsan',
#   'tower',
#   'really',
#   'want',
#   'spend',
#   'wait',
#   'sunday',
#   'even',
#   'think',
#   'would',
#   'great',
#   'opportunity',
#   'quiet',
#   'time',
#   'hotel',
#   'could',
#   'tower',
#   'taxi',
#   'would',
#   'cost',
#   'taxi',
#   'point',
#   'picture',
#   'cell',
#   'phone',
#   'north',
#   'tower',
#   'depart',
#   'hotel',
#   'know',
#   'taxis',
#   'individuals',
#   'allow',
#   'enter',
#   'drop',
#   'north',
#   'tower',
#   'drop',
#   'cable',
#   'lift',
#   'line',
#   'people',
#   'wait',
#   'approximately',
#   'hour',
#   'lift',
#   'enter',
#   'ticket',
#   'tower',
#   'observation',
#   'deck',
#   'people',
#   'upstairs',
#   'pretty',
#   'foggy',
#   'night',
#   'view',
#   'great',
#   'back',
#   'lineup',
#   'approximately',
#   'minutes',
#   'elevator',
#   'back',
#   'good',
#   'experience',
#   'wouldve',
#   'better',
#   'wasnt',
#   'foggy',
#   'head',
#   'back',
#   'cable',
#   'round',
#   'trip',
#   'ticket',
#   '1045',
#   'cable',
#   'close',
#   'line',
#   'cable',
#   'approximately',
#   'three',
#   'time',
#   'longer',
#   'first',
#   'time',
#   'come',
#   'know',
#   'would',
#   'stick',
#   'line',
#   'least',
#   'hours',
#   'walk',
#   'mountain',
#   'minutes',
#   'still',
#   'recommend',
#   'experience',
#   'suggest',
#   'things',
#   'number',
#   'make',
#   'sure',
#   'foggy',
#   'number',
#   'dont',
#   'cable',
#   'unless',
#   'dont',
#   'mind',
#   'wait',
#   'city',
#   'available',
#   'side',
#   'mountain',
#   'drop',
#   'return',
#   'back',
#   'afterwards'],
#  ['nice',
#   'namsan',
#   'cable',
#   'ride',
#   'nice',
#   'view',
#   'city',
#   'nothing',
#   'compare',
#   'peak',
#   'view'],
#  ['line',
#   'take',
#   'ticket',
#   'around',
#   '730pm',
#   'would',
#   'wait',
#   'great',
#   'wait',
#   'view',
#   'night',
#   'aint',
#   'nothing',
#   'special',
#   'observatory',
#   'night',
#   'moreover',
#   'many',
#   'light',
#   'floor',
#   'give',
#   'reflect',
#   'many',
#   'picture',
#   'restroom',
#   'skywalk',
#   'restroom',
#   'windows',
#   'queue',
#   'start',
#   'floor',
#   'elevator',
#   'complete',
#   'floor',
#   'line',
#   'never',
#   'ticket',
#   'lower',
#   'area',
#   'access',
#   'observatory',
#   'least',
#   'line',
#   'tower',
#   'without',
#   'enough',
#   'also',
#   'view'],
#  ['worth',
#   'understand',
#   'three',
#   'stag',
#   'tower',
#   'quite',
#   'worthwhile',
#   'clear',
#   'days',
#   'enjoy',
#   'view',
#   'pavement',
#   'level',
#   'minutes',
#   'walk',
#   'main',
#   'shop',
#   'area',
#   'step',
#   'lower',
#   'funicular',
#   'station',
#   'free',
#   'lift',
#   'lower',
#   'cable',
#   'station',
#   'funicular',
#   'single',
#   'shuttle',
#   'dozen',
#   'people',
#   'incline',
#   'smooth',
#   'stage',
#   'cable',
#   'shuttle',
#   'dozen',
#   'people',
#   'mountain',
#   'cars',
#   'small',
#   'charge',
#   'also',
#   'smooth',
#   'actual',
#   'tower',
#   'third',
#   'stage',
#   'need',
#   'wish',
#   'cable',
#   'take',
#   'small',
#   'park',
#   'area',
#   'seem',
#   'pleasantly',
#   'cooler',
#   'nice',
#   'wander',
#   'round',
#   'view',
#   'city',
#   'take',
#   'picture',
#   'believe',
#   'events',
#   'sometimes',
#   'worthwhile',
#   'visitors',
#   'couple',
#   'spare',
#   'hours',
#   'fresh'],
#  ['start',
#   'experience',
#   'take',
#   'namsan',
#   'cable',
#   'tower',
#   'drive',
#   'straight',
#   'tower',
#   'quite',
#   'early',
#   'shortly',
#   'open',
#   'operation',
#   'scenery',
#   'nice',
#   'behold',
#   'depend',
#   'weather',
#   'personally',
#   'night',
#   'time',
#   'better',
#   'time'],
#  ['place',
#   'give',
#   'captivate',
#   'sight',
#   'night',
#   'beauty',
#   'build',
#   'light',
#   'like',
#   'star',
#   'twinkle',
#   'space',
#   'watch'],
#  ['lovely',
#   'place',
#   'take',
#   'walk',
#   'tower',
#   'would',
#   'nice',
#   'tower',
#   'night',
#   'light',
#   'beautiful',
#   'scenery',
#   'tower',
#   'weather',
#   'great',
#   'regret',
#   'visit',
#   'tower',
#   'romantic',
#   'place',
#   'couple',
#   'highly',
#   'recommend'],
#  ['well',
#   'worth',
#   'trip',
#   'quite',
#   'steep',
#   'walk',
#   'park',
#   'area',
#   'elevator',
#   'main',
#   'view',
#   'level',
#   'super',
#   'fast',
#   'accompany',
#   'sound',
#   'light',
#   'show',
#   'ceilingthe',
#   'degree',
#   'view',
#   'tower',
#   'show',
#   'entertainment',
#   'lower',
#   'level'],
#  ['wonderful', 'place', 'city', 'hill', 'really', 'recommend', 'must'],
#  ['dont',
#   'realize',
#   'large',
#   'take',
#   'view',
#   'hopefully',
#   'clear',
#   'otherwise',
#   'could',
#   'disappoint',
#   'must',
#   'walk',
#   'trek',
#   'tower',
#   'worth',
#   'take',
#   'city',
#   'mountain'],
#  ['tower',
#   'mountain',
#   'access',
#   'elevator',
#   'line',
#   'elevator',
#   'longer',
#   'afternoon',
#   'approachesthe',
#   'view',
#   'spectacular',
#   'best',
#   'morning',
#   'quality',
#   'good'],
#  ['take',
#   'taxi',
#   'hotel',
#   'cable',
#   'station',
#   'book',
#   'ticket',
#   'would',
#   'like',
#   'enjoy',
#   'walk',
#   'cable',
#   'take',
#   'mountain',
#   'dont',
#   'recommend',
#   'observation',
#   'roof',
#   'unless',
#   'want',
#   'advice',
#   'enjoy',
#   'view',
#   'explore',
#   'area',
#   'walk',
#   'around',
#   'follow',
#   'sign'],
#  ['namsan',
#   'tower',
#   'famous',
#   'lover',
#   'lock',
#   'love',
#   'tower',
#   'however',
#   'place',
#   'suitable',
#   'everyone',
#   'people',
#   'also',
#   'come',
#   'family',
#   'friends',
#   'think',
#   'best',
#   'catch',
#   'sunset',
#   'hill',
#   'especially',
#   'spring',
#   'snap',
#   'picture',
#   'also',
#   'whole',
#   'light',
#   'best',
#   'cheapest',
#   'take',
#   'dongguk',
#   'university',
#   'station',
#   'exit',
#   'directly',
#   'take',
#   'bottom',
#   'tower',
#   'take',
#   'cable',
#   'romantic',
#   'feel',
#   'walk',
#   'mountain',
#   'pass',
#   'thru',
#   'park',
#   'towards',
#   'tower',
#   'good',
#   'exercise'],
#  ['basic',
#   'tower',
#   'experience',
#   'zoomy',
#   'ride',
#   'full',
#   'round',
#   'view',
#   'snack',
#   'souvenirs',
#   'want',
#   'since',
#   'tower',
#   'already',
#   'hill',
#   'miles',
#   'windows',
#   'keep',
#   'clean',
#   'photos',
#   'base',
#   'zero',
#   'dollar',
#   'view',
#   'point',
#   'kitsch',
#   'also',
#   'ride',
#   'cable',
#   'base',
#   'feature'],
#  ['night',
#   'view',
#   'tower',
#   'amaze',
#   'definitely',
#   'worth',
#   'climb',
#   'also',
#   'quite',
#   'activities',
#   'options',
#   'well',
#   'similar',
#   'victorias',
#   'peak',
#   'hong',
#   'kong',
#   'check',
#   'lovers',
#   'lock',
#   'bridge',
#   'nice',
#   'photo',
#   'take',
#   'spot',
#   'screen',
#   'experience',
#   'really',
#   'entertain',
#   'bring',
#   'world',
#   'amaze',
#   'graphics'],
#  ['visit',
#   'tower',
#   'april',
#   'even',
#   'take',
#   'cable',
#   'think',
#   'would',
#   'take',
#   'right',
#   'bottom',
#   'tower',
#   'however',
#   'wait',
#   'almost',
#   'minutes',
#   'long',
#   'queue',
#   'take',
#   'platform',
#   'still',
#   'take',
#   'staircase',
#   'ticket',
#   'booth',
#   'enjoy',
#   'sunset',
#   'view',
#   'observation',
#   'deck',
#   'breathtaking',
#   'maybe',
#   'good',
#   'place',
#   'lovers',
#   'landmark'],
#  ['cable',
#   'quite',
#   'long',
#   'even',
#   'nonetheless',
#   'quick',
#   'process',
#   'view',
#   'breathtaking',
#   'trip',
#   'observation',
#   'deck',
#   'must',
#   'appropriate',
#   'children',
#   'families',
#   'well',
#   'solo',
#   'travelers',
#   'view',
#   'sunset',
#   'great'],
#  ['help',
#   'perspective',
#   'amaze',
#   'city',
#   'view',
#   'breath',
#   'take',
#   'walk',
#   'tower',
#   'beautiful',
#   'garden',
#   'cable'],
#  ['good',
#   'walk',
#   'cablecar',
#   'arrive',
#   'view',
#   'incredible',
#   'great',
#   'vantage',
#   'point',
#   'must',
#   'visit'],
#  ['visit',
#   'nseoul',
#   'tower',
#   'namsan',
#   'tower',
#   'noon',
#   'bite',
#   'though',
#   'early',
#   'april',
#   'lead',
#   'stop',
#   'tower',
#   'bite',
#   'steep',
#   'difficult',
#   'walk',
#   'scene',
#   'around',
#   'tower',
#   'beautiful',
#   'could',
#   'inner',
#   'city',
#   'even',
#   'palaces',
#   'seem',
#   'must',
#   'tourists',
#   'especially',
#   'couple',
#   'come',
#   'hang',
#   'love',
#   'lock',
#   'need',
#   'ticket',
#   'observation',
#   'deck',
#   'unless',
#   'youd',
#   'like',
#   'floor',
#   'beautiful',
#   'city',
#   'front'],
#  ['awesome',
#   'lock',
#   'tower',
#   'cost',
#   '10000',
#   'worth',
#   'watch',
#   'showtime',
#   'also',
#   'potato',
#   'stick',
#   'haha',
#   'cute',
#   'gift',
#   'shop',
#   'tower',
#   'accessible',
#   'ways',
#   'ride',
#   'subway',
#   'place',
#   'ride',
#   'lift',
#   'ride',
#   'lift',
#   'hike',
#   'hill',
#   'sister',
#   'ride',
#   'lift',
#   'hike',
#   'trail',
#   'stairs',
#   'super',
#   'place',
#   'play',
#   'also',
#   'exercise',
#   'want',
#   'water',
#   'convenience',
#   'store',
#   'also',
#   'cafe'],
#  ['visit',
#   'start',
#   'cloud',
#   'base',
#   'tower',
#   'least',
#   'four',
#   'different',
#   'areas',
#   'great',
#   'view',
#   'mountains',
#   'city',
#   'like',
#   'review',
#   'save',
#   'buck',
#   'every',
#   'live',
#   'show',
#   'base',
#   'tower',
#   'free'],
#  ...]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

te = TransactionEncoder()
te_ary = te.fit(text_arr).transform(text_arr)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#        000won  015min  020305  030504  04340   0801   0900  09001900   0930  \
# 0       False   False   False   False  False  False  False     False  False
# 1       False   False   False   False  False  False  False     False  False
# 2       False   False   False   False  False  False  False     False  False
# 3       False   False   False   False  False  False  False     False  False
# 4       False   False   False   False  False  False  False     False  False
# ...       ...     ...     ...     ...    ...    ...    ...       ...    ...
# 15460   False   False   False   False  False  False  False     False  False
# 15461   False   False   False   False  False  False  False     False  False
# 15462   False   False   False   False  False  False  False     False  False
# 15463   False   False   False   False  False  False  False     False  False
# 15464   False   False   False   False  False  False  False     False  False
#
#         1000  ...   zone  zonemagic  zookeeper  zookeepers   zoom  zoomin  \
# 0      False  ...  False      False      False       False  False   False
# 1      False  ...  False      False      False       False  False   False
# 2      False  ...  False      False      False       False  False   False
# 3      False  ...  False      False      False       False  False   False
# 4      False  ...  False      False      False       False  False   False
# ...      ...  ...    ...        ...        ...         ...    ...     ...
# 15460  False  ...  False      False      False       False  False   False
# 15461  False  ...  False      False      False       False  False   False
# 15462  False  ...  False      False      False       False  False   False
# 15463  False  ...  False      False      False       False  False   False
# 15464  False  ...  False      False      False       False  False   False
#
#        zoomy   zoos  zucchini  zumagansan
# 0      False  False     False       False
# 1      False  False     False       False
# 2      False  False     False       False
# 3      False  False     False       False
# 4      False  False     False       False
# ...      ...    ...       ...         ...
# 15460  False  False     False       False
# 15461  False  False     False       False
# 15462  False  False     False       False
# 15463  False  False     False       False
# 15464  False  False     False       False
#
# [15465 rows x 14053 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True)
df=pd.DataFrame(frequent_itemsets)
#association_rules(frequent_itemsets, metric="lift", min_threshold=1)
df['length']=df['itemsets'].apply(lambda x:len(x))
df = df[(df['length']==2)&(df['support']>=0.01)].sort_values(by='support',ascending=False)

# %%
df
# Out:
#      support        itemsets  length
# 87  0.156288   (view, tower)       2
# 83  0.091562    (view, take)       2
# 82  0.091497   (tower, take)       2
# 62  0.084837  (tower, cable)       2
# 63  0.084707   (view, cable)       2
# 65  0.083802    (view, city)       2
# 75  0.079082   (shop, place)       2
# 64  0.073068   (tower, city)       2
# 89  0.070676    (view, walk)       2
# 88  0.069124   (tower, walk)       2
# 61  0.068283   (take, cable)       2
# 84  0.067701    (walk, take)       2
# 66  0.066796   (good, place)       2
# 79  0.066537   (view, place)       2
# 70  0.066343   (view, great)       2
# 74  0.063886   (view, night)       2
# 68  0.062011  (great, place)       2
# 78  0.060912  (tower, place)       2
# 76  0.058390   (take, place)       2
# 71  0.056838   (nice, place)       2
# 86  0.054769    (view, time)       2
# 77  0.054381   (place, time)       2
# 67  0.054122    (view, good)       2
# 80  0.053734   (walk, place)       2
# 85  0.053411   (tower, time)       2
# 73  0.052376  (tower, night)       2
# 72  0.052376    (view, nice)       2
# 69  0.051342  (tower, great)       2
# 81  0.050824    (take, time)       2
# 60  0.050436   (place, also)       2

# %%
G=nx.Graph()
edges=[]
for i in df['itemsets']:
    i=tuple(i)
    edges.append(i)


G.add_edges_from(edges)

# %%
#association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
import scipy.stats
pr=nx.pagerank(G)
nsize=np.array([v for v in pr.values()])
nsize=2000*(nsize-min(nsize))/(max(nsize)-min(nsize))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\link_analysis\pagerank_alg.py:108: DeprecationWarning: networkx.pagerank_scipy is deprecated and will be removed in NetworkX 3.0, use networkx.pagerank instead.
#   return pagerank_scipy(

# %%
pos = pos=nx.spring_layout(G)

# %%
plt.figure(figsize=(16,12))
plt.axis('off')
nx.draw_networkx(G,font_family='framd.ttf',font_size=16,pos=pos,node_color=list(pr.values()),node_size=nsize,alpha=0.7,edge_color='#FFDEA2')
plt.savefig("network1.png")
# Out:
# findfont: Font family ['framd.ttf'] not found. Falling back to DejaVu Sans.

# %%
import gensim
from gensim.corpora.dictionary import Dictionary
from gensim.models import CoherenceModel

dictionary =Dictionary(text_arr)
corpus =[dictionary.doc2bow(text) for text in text_arr]
coherence_values=[]
for i in range(2,15):
    ldamodel=gensim.models.ldamodel.LdaModel(corpus,num_topics=i,id2word=dictionary)
    coherence_model_lda=CoherenceModel(model=ldamodel,texts=text_arr,dictionary=dictionary,topn=10)
    coherence_lda=coherence_model_lda.get_coherence()
    coherence_values.append(coherence_lda)

# %%
x=range(2,15)
plt.plot(x,coherence_values)
plt.xlabel("number of topics")
plt.ylabel("coherence score")
plt.show()
